# %% [markdown]
# ## Preparation

# %%
import os
import sys
parent_dir = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.append(parent_dir)
from pathlib import Path
import json
import numpy as np
from matplotlib import pyplot as plt
from scipy.spatial import Voronoi, voronoi_plot_2d

from clustering.patchwork_visualization import create_plot_and_save_patchwork
from patchwork import Patchwork, create_patchwork
from datasets.data_reconstruction import get_and_reconstruct_data, reconstruct_solver_and_grid

# %matplotlib inline
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='4e7fe9eb-b0b4-4ebc-b8f5-cbcf1e1d28f2'>
#   <div id="c8fcf6e0-76ed-40ad-afd1-660d05184fef" data-root-id="4e7fe9eb-b0b4-4ebc-b8f5-cbcf1e1d28f2" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
results_dir = os.path.join(parent_dir, 'datasets', 'results')
OUTPUT_DIR = Path.cwd().parent/ "datasets" / "results"

# %%
run_ids = lambda run_dict, model_name, key: run_dict[model_name][key]['run_ids']
def title(run_dict, model_name, key, entropy_strategy = "ShannonEntropyOnlyMerged", entropy_measure = 'shannon_entropy'): 
    return f"<h3> {model_name} <br />timestep: {run_dict[model_name][key]['delta_t']} <br /> samples per cell: {run_dict[model_name][key]['num_samples_per_cell']}  <br /> transformation: {run_dict[model_name][key]['transformations']}<br /> Entropy Strategy: {entropy_strategy}<br /> Entropy Measure: {entropy_measure}</h3>  <br />"

# %% [markdown]
# ## Test Voronoi

# %%
db_name = os.path.join(results_dir, 'simple-models_voronoi_results_test.db')
with open(OUTPUT_DIR / "simple-models_voronoi_test_run-dict.json", "r") as file:
    run_dict = json.load(file)

# %%
entropy_strategy = 'ShannonEntropyAll' #'ShannonEntropyOnlyMerged'
loss_function = 'TransitionAndSizeEntropyLoss'
entropy_measure = 'conditional_shannon_entropy' #'shannon_entropy'
coeff = 0.03

# %%
table_name = 'StableNode_c' 
path = "./results/StableNode/notrafo/voronoi"
model_name = 'StableNode'
key = '2'

# %%
p, controls,solver = create_patchwork(db_name, table_name, run_ids(run_dict, model_name, key))
# Out:
# All configurations are the same: True
# (6095, 2)
# Percentage of data rows deleted: 0.00%

# %%
from data_generation.simulations.simulator import Simulator
sim = Simulator(p.grid, solver.model, solver)
c, tf_centers, der, tf_der = sim.get_gridcell_centers_and_derivatives(controls)

# %%
fig = plt.figure(figsize=(5, 5))
voronoi_plot_2d(p.grid.voronoi, ax=plt.gca(), show_vertices=False, line_colors='black', line_width=0.8, line_alpha=0.7, point_size=2)
plt.quiver(
    tf_centers[:, 0], tf_centers[:, 1],  # start points
    0.079*tf_der[0, :, 0], 0.079*tf_der[0, :, 1],    # vector components
    angles='xy', scale_units='xy', scale=1, color='darkgreen', width=0.003, label='tf_der vectors'
)
plt.xlim(p.grid.tf_bounds[0])
plt.ylim(p.grid.tf_bounds[1])
plt.gca().set_aspect('equal', adjustable='box')
plt.show()

# %%
create_plot_and_save_patchwork(db_name, table_name, run_ids(run_dict, model_name, key), 
                                   entropy_strategy_strg=entropy_strategy, 
                                   entropy_measure = entropy_measure,
                                   loss_function_strg=loss_function, 
                                   loss_function_coeff=0.1, 
                                   path_to_save= None, title_interactive=title(run_dict, model_name, key, entropy_strategy, entropy_measure), show_interactive=True)
# Out:
# All configurations are the same: True
# (6095, 2)
# Percentage of data rows deleted: 0.00%
# Step 0, number of patches: 1036, time: 0.00
# Step 100, number of patches: 936, time: 1.66
# Step 200, number of patches: 836, time: 3.16
# Step 300, number of patches: 736, time: 4.60
# Step 400, number of patches: 636, time: 5.82
# Step 500, number of patches: 536, time: 7.03
# Step 600, number of patches: 436, time: 8.10
# Step 700, number of patches: 336, time: 9.06
# Step 800, number of patches: 236, time: 9.92
# Step 900, number of patches: 136, time: 10.74
# Step 1000, number of patches: 36, time: 11.74
# No more patches to merge
# Done, after 1035 steps
# Launching server at http://localhost:38143
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='81205ad0-4003-49a0-bab2-4a48a7e0955e', ...)
# ...

# %%
table_name = 'Movable2Stable1SaddlePoint_h' 
model_name = 'Movable2Stable1SaddlePoint'
key = '2'
create_plot_and_save_patchwork(db_name, table_name, run_ids(run_dict, model_name, key), 
                                   entropy_strategy_strg=entropy_strategy, 
                                   entropy_measure = entropy_measure,
                                   loss_function_strg=loss_function, 
                                   loss_function_coeff=0.15, 
                                   path_to_save= None, title_interactive=title(run_dict, model_name, key, entropy_strategy, entropy_measure), show_interactive=True)
# Out:
# All configurations are the same: True
# (6179, 2)
# Percentage of data rows deleted: 0.00%
# Step 0, number of patches: 1051, time: 0.00
# Step 100, number of patches: 951, time: 1.44
# Step 200, number of patches: 851, time: 2.64
# Step 300, number of patches: 751, time: 3.99
# Step 400, number of patches: 651, time: 5.10
# Step 500, number of patches: 551, time: 6.12
# Step 600, number of patches: 451, time: 7.09
# Step 700, number of patches: 351, time: 7.93
# Step 800, number of patches: 251, time: 8.69
# Step 900, number of patches: 151, time: 9.35
# Step 1000, number of patches: 51, time: 9.97
# No more patches to merge
# Done, after 1050 steps
# Launching server at http://localhost:40029
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='9bc80d67-ea22-4efd-a2da-656d8a607095', ...)
# ...

# %% [markdown]
# ## Visualization

# %% [markdown]
# ### Simple Models

# %% [markdown]
# #### Single Tests

# %%
db_name = os.path.join(results_dir, 'simple-models_results.db')
with open(OUTPUT_DIR / "simple-models_run-dict.json", "r") as file:
    run_dict = json.load(file)


entropy_strategy = 'ShannonEntropyAll' #'ShannonEntropyOnlyMerged'
loss_function = 'TransitionAndSizeEntropyLoss'
entropy_measure = 'conditional_shannon_entropy' #'shannon_entropy'
loss_function_coeff = [0, 0.03, 0.1, 0.3, 0.5]
coeff = 0.03

# %%
table_name = 'StableNode_c' 
path = "./results/StableNode/notrafo/first_clustering"
model_name = 'StableNode'

key = '1' #'2' #1 for (30x30), '2' for (5x5)
create_plot_and_save_patchwork(db_name, table_name, run_ids(run_dict, model_name, key), 
                                entropy_strategy_strg=entropy_strategy, 
                                entropy_measure = entropy_measure,
                                loss_function_strg=loss_function, 
                                loss_function_coeff=0.05, 
                                path_to_save= None, title_interactive=title(run_dict, model_name, key, entropy_strategy, entropy_measure), show_interactive=True)
# Out:
# All configurations are the same: True
# Percentage of data rows deleted: 0.00%
# Step 0, number of patches: 900, time: 0.00
# Step 100, number of patches: 800, time: 1.42
# Step 200, number of patches: 700, time: 2.72
# Step 300, number of patches: 600, time: 4.08
# Step 400, number of patches: 500, time: 5.23
# Step 500, number of patches: 400, time: 6.26
# Step 600, number of patches: 300, time: 7.26
# Step 700, number of patches: 200, time: 8.21
# Step 800, number of patches: 100, time: 8.90
# No more patches to merge
# Done, after 899 steps
# Launching server at http://localhost:37373
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='ca9bce09-073b-4da3-9f28-512c3e88540f', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='ff89e6f4-79ea-4b53-972f-7a0e256488bf', ...)
# ...

# %%
table_name = 'Movable2Stable1SaddlePoint_h' 
path = "./results/Movable2Stable1SaddlePoint/notrafo/first_clustering"
model_name = 'Movable2Stable1SaddlePoint'
key = '2'

# %%
key = '1' #1action
create_plot_and_save_patchwork(db_name, table_name, run_ids(run_dict, model_name, key), 
                                   entropy_strategy_strg=entropy_strategy, 
                                   entropy_measure = entropy_measure,
                                   loss_function_strg=loss_function, 
                                   loss_function_coeff=0.05, 
                                   path_to_save= None, title_interactive=title(run_dict, model_name, key, entropy_strategy), show_interactive=True)
# Out:
# All configurations are the same: True
# Percentage of data rows deleted: 0.00%
# Step 0, number of patches: 900, time: 0.00
# Step 100, number of patches: 800, time: 1.42
# Step 200, number of patches: 700, time: 3.04
# Step 300, number of patches: 600, time: 4.66
# Step 400, number of patches: 500, time: 6.31
# Step 500, number of patches: 400, time: 8.08
# Step 600, number of patches: 300, time: 9.67
# Step 700, number of patches: 200, time: 10.69
# Step 800, number of patches: 100, time: 11.57
# No more patches to merge
# Done, after 899 steps
# Launching server at http://localhost:33391
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='0a418e4d-f8d2-4f7a-8f66-9d2275ff0b13', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='21fb8147-b348-42c9-a7f2-f1173a59c27f', ...)
# ...

# %%
key = '2'

create_plot_and_save_patchwork(db_name, table_name, run_ids(run_dict, model_name, key), 
                                   entropy_strategy_strg=entropy_strategy, 
                                   entropy_measure = entropy_measure,
                                   loss_function_strg=loss_function, 
                                   loss_function_coeff=0.05, 
                                   path_to_save= None, title_interactive=title(run_dict, model_name, key, entropy_strategy), show_interactive=True)
# Out:
# All configurations are the same: True
# Percentage of data rows deleted: 0.00%
# Step 0, number of patches: 1600, time: 0.00
# Step 100, number of patches: 1500, time: 4.76
# Step 200, number of patches: 1400, time: 9.82
# Step 300, number of patches: 1300, time: 14.07
# Step 400, number of patches: 1200, time: 17.83
# Step 500, number of patches: 1100, time: 21.65
# Step 600, number of patches: 1000, time: 25.38
# Step 700, number of patches: 900, time: 29.08
# Step 800, number of patches: 800, time: 32.38
# Step 900, number of patches: 700, time: 35.51
# Step 1000, number of patches: 600, time: 38.32
# Step 1100, number of patches: 500, time: 40.73
# Step 1200, number of patches: 400, time: 43.03
# Step 1300, number of patches: 300, time: 45.06
# Step 1400, number of patches: 200, time: 47.05
# Step 1500, number of patches: 100, time: 48.65
# No more patches to merge
# Done, after 1599 steps
# Launching server at http://localhost:36055
# ...

# %%
for coeff in loss_function_coeff:
    print(f"Creating patchwork for {model_name} with key {key} and coeff {coeff}")
    create_plot_and_save_patchwork(db_name, table_name, run_ids(run_dict, model_name, key), 
                                   entropy_strategy_strg=entropy_strategy, 
                                   entropy_measure = entropy_measure,
                                   loss_function_strg=loss_function, 
                                   loss_function_coeff=coeff, 
                                   path_to_save= None, title_interactive=title(run_dict, model_name, key, entropy_strategy), show_interactive=True)
# Out:
# Creating patchwork for Movable2Stable1SaddlePoint with key 2 and coeff 0
# All configurations are the same: True
# Percentage of data rows deleted: 0.00%
# Step 0, number of patches: 1600, time: 0.00
# Step 100, number of patches: 1500, time: 5.63
# Step 200, number of patches: 1400, time: 10.90
# Step 300, number of patches: 1300, time: 15.87
# Step 400, number of patches: 1200, time: 21.53
# Step 500, number of patches: 1100, time: 27.13
# Step 600, number of patches: 1000, time: 32.44
# Step 700, number of patches: 900, time: 36.40
# Step 800, number of patches: 800, time: 40.17
# Step 900, number of patches: 700, time: 43.12
# Step 1000, number of patches: 600, time: 46.65
# Step 1100, number of patches: 500, time: 49.77
# Step 1200, number of patches: 400, time: 52.72
# Step 1300, number of patches: 300, time: 55.24
# Step 1400, number of patches: 200, time: 57.40
# Step 1500, number of patches: 100, time: 61.51
# No more patches to merge
# Done, after 1599 steps
# ...

# %%
table_name = 'Stretchable2Stable1SaddlePoint_h' 
path = "./results/Stretchable2Stable1SaddlePoint/notrafo/first_clustering"
model_name = 'Stretchable2Stable1SaddlePoint'

key = '2'
create_plot_and_save_patchwork(db_name, table_name, run_ids(run_dict, model_name, key), 
                                   entropy_strategy_strg=entropy_strategy, 
                                   entropy_measure = entropy_measure,
                                   loss_function_strg=loss_function, 
                                   loss_function_coeff=coeff, 
                                   path_to_save= None, title_interactive=title(run_dict, model_name, key, entropy_strategy), show_interactive=True)
# Out:
# All configurations are the same: True
# Percentage of data rows deleted: 0.00%
# Step 0, number of patches: 1600, time: 0.00
# Step 100, number of patches: 1500, time: 6.21
# Step 200, number of patches: 1400, time: 12.98
# Step 300, number of patches: 1300, time: 19.47
# Step 400, number of patches: 1200, time: 24.37
# Step 500, number of patches: 1100, time: 31.84
# Step 600, number of patches: 1000, time: 35.63
# Step 700, number of patches: 900, time: 42.58
# Step 800, number of patches: 800, time: 46.07
# Step 900, number of patches: 700, time: 50.03
# Step 1000, number of patches: 600, time: 53.69
# Step 1100, number of patches: 500, time: 57.01
# Step 1200, number of patches: 400, time: 59.60
# Step 1300, number of patches: 300, time: 61.89
# Step 1400, number of patches: 200, time: 64.19
# Step 1500, number of patches: 100, time: 66.05
# No more patches to merge
# Done, after 1599 steps
# Launching server at http://localhost:33289
# ...

# %%
table_name = 'Stretchable2Stable1SaddlePoint_h' 
path = "./results/Stretchable2Stable1SaddlePoint/notrafo/first_clustering"
model_name = 'Stretchable2Stable1SaddlePoint'

key = '2'
create_plot_and_save_patchwork(db_name, table_name, run_ids(run_dict, model_name, key), 
                                   entropy_strategy_strg=entropy_strategy, 
                                   entropy_measure = entropy_measure,
                                   loss_function_strg=loss_function, 
                                   loss_function_coeff=coeff, 
                                   path_to_save= None, title_interactive=title(run_dict, model_name, key, entropy_strategy), show_interactive=True)
# Out:
# All configurations are the same: True
# Percentage of data rows deleted: 0.00%
# Step 0, number of patches: 1600, time: 0.00
# Step 100, number of patches: 1500, time: 7.78
# Step 200, number of patches: 1400, time: 15.13
# Step 300, number of patches: 1300, time: 22.32
# Step 400, number of patches: 1200, time: 28.80
# Step 500, number of patches: 1100, time: 35.29
# Step 600, number of patches: 1000, time: 41.87
# Step 700, number of patches: 900, time: 46.39
# Step 800, number of patches: 800, time: 51.37
# Step 900, number of patches: 700, time: 56.83
# Step 1000, number of patches: 600, time: 60.46
# Step 1100, number of patches: 500, time: 63.34
# Step 1200, number of patches: 400, time: 65.92
# Step 1300, number of patches: 300, time: 68.65
# Step 1400, number of patches: 200, time: 71.09
# Step 1500, number of patches: 100, time: 73.36
# No more patches to merge
# Done, after 1599 steps
# Launching server at http://localhost:39313
# ...

# %%
table_name = 'TwoStableNodesOneSaddlePoint_c' 
path = "./results/TwoStableNodesOneSaddlePoint/notrafo/first_clustering"
model_name = 'TwoStableNodesOneSaddlePoint'

# %%
key = '2' #1control
create_plot_and_save_patchwork(db_name, table_name, run_ids(run_dict, model_name, key), 
                                   entropy_strategy_strg=entropy_strategy, 
                                   entropy_measure = entropy_measure,
                                   loss_function_strg=loss_function, 
                                   loss_function_coeff=coeff, 
                                   path_to_save= None, title_interactive=title(run_dict, model_name, key, entropy_strategy), show_interactive=True)

# %%
key = '1' #2controls
create_plot_and_save_patchwork(db_name, table_name, run_ids(run_dict, model_name, key), 
                                   entropy_strategy_strg=entropy_strategy, 
                                   entropy_measure = entropy_measure,
                                   loss_function_strg=loss_function, 
                                   loss_function_coeff=coeff, 
                                   path_to_save= None, title_interactive=title(run_dict, model_name, key, entropy_strategy), show_interactive=True)
# Out:
# All configurations are the same: True
# Percentage of data rows deleted: 0.00%
# Step 0, number of patches: 900, time: 0.00
# Step 100, number of patches: 800, time: 3.62
# Step 200, number of patches: 700, time: 8.02
# Step 300, number of patches: 600, time: 13.27
# Step 400, number of patches: 500, time: 19.00
# Step 500, number of patches: 400, time: 22.37
# Step 600, number of patches: 300, time: 24.59
# Step 700, number of patches: 200, time: 26.31
# Step 800, number of patches: 100, time: 27.62
# No more patches to merge
# Done, after 899 steps
# Launching server at http://localhost:42297
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='eea398a7-6a76-4d3a-9167-0f2bd9c49c89', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='921ce43e-c1e7-4e85-a9b6-ba1c60bba045', ...)
# ...

# %%
key = '1' #2controls
create_plot_and_save_patchwork(db_name, table_name, run_ids(run_dict, model_name, key), 
                                   entropy_strategy_strg=entropy_strategy, 
                                   entropy_measure = entropy_measure,
                                   loss_function_strg=loss_function, 
                                   loss_function_coeff=coeff, 
                                   path_to_save= None, title_interactive=title(run_dict, model_name, key, entropy_strategy), show_interactive=True)
# Out:
# All configurations are the same: True
# Percentage of data rows deleted: 0.00%
# Step 0, number of patches: 900, time: 0.00
# Step 100, number of patches: 800, time: 3.76
# Step 200, number of patches: 700, time: 8.20
# Step 300, number of patches: 600, time: 13.39
# Step 400, number of patches: 500, time: 18.89
# Step 500, number of patches: 400, time: 22.45
# Step 600, number of patches: 300, time: 24.36
# Step 700, number of patches: 200, time: 26.05
# Step 800, number of patches: 100, time: 27.41
# No more patches to merge
# Done, after 899 steps
# Launching server at http://localhost:40237
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='cb1bd0db-f6ea-4c27-87f8-3fe0eafdb9d1', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='eef35939-7ed9-4a5c-b192-2887aba32a23', ...)
# ...

# %%
table_name = 'UniformFlow_c' 
path = "./results/UniformFlow/logistictrafo/first_clustering"
model_name = 'UniformFlow'
key = '2'
create_plot_and_save_patchwork(db_name, table_name, run_ids(run_dict, model_name, key), 
                                   entropy_strategy_strg=entropy_strategy, 
                                   entropy_measure = entropy_measure,
                                   loss_function_strg=loss_function, 
                                   loss_function_coeff=coeff, 
                                   path_to_save= None, title_interactive=title(run_dict, model_name, key, entropy_strategy), show_interactive=True)
# Out:
# All configurations are the same: True
# Percentage of data rows deleted: 1.63%
# Step 0, number of patches: 900, time: 0.00
# Step 100, number of patches: 800, time: 1.05
# Step 200, number of patches: 700, time: 2.35
# Step 300, number of patches: 600, time: 3.55
# Step 400, number of patches: 500, time: 4.53
# Step 500, number of patches: 400, time: 5.77
# Step 600, number of patches: 300, time: 6.47
# Step 700, number of patches: 200, time: 7.36
# Step 800, number of patches: 100, time: 7.76
# No more patches to merge
# Done, after 899 steps
# Launching server at http://localhost:40113
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='c61f5eba-4a60-4c5b-9af7-5217cb0c0e3f', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='22ce1f6b-beab-4ae0-a63c-60bfeb19f25c', ...)
# ...

# %% [markdown]
# #### Other

# %%
for coeff in loss_function_coeff:
    create_plot_and_save_patchwork(db_name, table_name, run_ids(run_dict, model_name, key), 
                                   entropy_strategy_strg=entropy_strategy, 
                                   entropy_measure = entropy_measure,
                                   loss_function_strg=loss_function, 
                                   loss_function_coeff=coeff, 
                                   path_to_save= None, title_interactive=title(run_dict, model_name, key, entropy_strategy), show_interactive=True)
# Out:
# All configurations are the same: True
# Percentage of data rows deleted: 0.00%
# Step 0, number of patches: 900, time: 0.00
# Step 100, number of patches: 800, time: 4.95
# Step 200, number of patches: 700, time: 10.97
# Step 300, number of patches: 600, time: 18.62
# Step 400, number of patches: 500, time: 25.86
# Step 500, number of patches: 400, time: 33.69
# Step 600, number of patches: 300, time: 36.64
# Step 700, number of patches: 200, time: 38.37
# Step 800, number of patches: 100, time: 39.85
# No more patches to merge
# Done, after 899 steps
# Launching server at http://localhost:37163
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='6fb987cd-0f61-403f-8e30-d1437e1cd71d', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='26e11aa7-cb03-4dae-a61d-2cf3b267482b', ...)
# ...

# %% [markdown]
# patchwork,_,_ = create_patchwork(
#     db_name,
#     table_name,
#     run_ids(run_dict, model_name, key),
#     entropy_strategy_strg=entropy_strategy,
#     loss_function_strg=loss_function,
#     loss_function_coeff=0.1)

# %% [markdown]
# ### FitzHugh-Nagumo Model

# %% [markdown]
# #### Test runs FHN

# %%
db_name = os.path.join(results_dir, 'fhn-model-results.db')

table_name = 'FitzHughNagumoModel_b_I' 
path = "./results/FitzHugh-Nagumo_Model/logistictrafo"
with open(OUTPUT_DIR / "fhn-model-run-dict.json", "r") as file:
    run_dict = json.load(file)

#fhn_run_ids = lambda key: run_dict['FitzHughNagumoModel'][key]['run_ids']
#fhn_title = lambda key: f"<h3> FitzHugh-Nagumo Model  <br />timestep: {run_dict['FitzHughNagumoModel'][key]['delta_t']} <br /> samples per cell: {run_dict['FitzHughNagumoModel'][key]['num_samples_per_cell']} </h3>  <br />"

model_name = 'FitzHughNagumoModel'
entropy_strategy = 'ShannonEntropyAll'
loss_function = 'TransitionEntropyLoss' #'TransitionAndSizeEntropyLoss'

# %%
fhn_keys = [#'1', #logistic trafo, 2 controls
            '5', #logistic trafo, 1 controls
            '8', #no trafo, 1 controls
            '10' #no trafo, 2 controls
            ]
fhn_loss_function_coeffs = [0]#,  0.03, 0.3] #[0, 0.015, 0.03, 0.05, 0.3]

# %%
for key in fhn_keys:
    for coef in fhn_loss_function_coeffs:
        create_plot_and_save_patchwork(db_name, table_name, run_ids(run_dict, model_name, key), 
                                    entropy_strategy_strg=entropy_strategy, 
                                    loss_function_strg=loss_function, 
                                    #loss_function_coeff=coef, 
                                    path_to_save= None, title_interactive=title(run_dict, model_name, key, entropy_strategy), show_interactive=True)
# Out:
# All configurations are the same: True
# Step 0, number of patches: 900, time: 0.00
# Step 100, number of patches: 800, time: 3.90
# Step 200, number of patches: 700, time: 8.67
# Step 300, number of patches: 600, time: 14.21
# Step 400, number of patches: 500, time: 20.22
# Step 500, number of patches: 400, time: 26.84
# Step 600, number of patches: 300, time: 32.54
# Step 700, number of patches: 200, time: 39.02
# Step 800, number of patches: 100, time: 46.13
# No more patches to merge
# Done, after 899 steps
# Launching server at http://localhost:43743
# All configurations are the same: True
# Percentage of data rows deleted: 0.00%
# Step 0, number of patches: 900, time: 0.00
# Step 100, number of patches: 800, time: 1.61
# Step 200, number of patches: 700, time: 2.98
# Step 300, number of patches: 600, time: 6.75
# Step 400, number of patches: 500, time: 10.00
# Step 500, number of patches: 400, time: 12.35
# Step 600, number of patches: 300, time: 14.49
# ...

# %% [markdown]
# #### Single Runs

# %%
key = '10'
for coef in fhn_loss_function_coeffs:
    create_plot_and_save_patchwork(db_name, table_name, run_ids(run_dict, model_name, key), 
                                   entropy_strategy_strg=entropy_strategy, 
                                   loss_function_strg=loss_function, 
                                   loss_function_coeff=coef, 
                                   path_to_save= None, title_interactive=title(run_dict, model_name, key, entropy_strategy), show_interactive=True)
# Out:
# All configurations are the same: True
# Percentage of data rows deleted: 0.00%
# Step 0, number of patches: 900, time: 0.00
# Step 100, number of patches: 800, time: 2.60
# Step 200, number of patches: 700, time: 5.19
# Step 300, number of patches: 600, time: 9.34
# Step 400, number of patches: 500, time: 13.56
# Step 500, number of patches: 400, time: 16.64
# Step 600, number of patches: 300, time: 20.14
# Step 700, number of patches: 200, time: 22.76
# Step 800, number of patches: 100, time: 25.32
# No more patches to merge
# Done, after 899 steps
# Launching server at http://localhost:45385
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='952344d7-b80c-4aa7-9312-d7d45cd86979', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='e0256603-95e8-47a4-8c40-d3b9c05f42b7', ...)
# ...

# %%
key = '1' #logistic trafo, 2 controls
create_plot_and_save_patchwork(db_name, table_name, run_ids(run_dict, model_name, key), entropy_strategy_strg=entropy_strategy, loss_function_strg=loss_function, path_to_save= None, title_interactive=title(run_dict, model_name, key, entropy_strategy), show_interactive=True)

# %%
key = '5' #logistic trafo, 1 controls
create_plot_and_save_patchwork(db_name, table_name, run_ids(run_dict, model_name, key), entropy_strategy_strg=entropy_strategy, loss_function_strg=loss_function, path_to_save= None, title_interactive=title(run_dict, model_name, key, entropy_strategy), show_interactive=True)
# Out:
# All configurations are the same: True
# Step 0, number of patches: 900, time: 0.00
# Step 100, number of patches: 800, time: 1.99
# Step 200, number of patches: 700, time: 3.85
# Step 300, number of patches: 600, time: 5.98
# Step 400, number of patches: 500, time: 8.19
# Step 500, number of patches: 400, time: 10.50
# Step 600, number of patches: 300, time: 11.98
# Step 700, number of patches: 200, time: 13.43
# Step 800, number of patches: 100, time: 14.47
# No more patches to merge
# Done, after 899 steps
# Launching server at http://localhost:43079
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='6163c2b2-5502-4889-bd22-00387abe2f6b', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='d4cf8362-1974-4cfd-bb42-e9646d8bd7a9', ...)
# ...

# %%
key = '7' #no trafo, 1 controls
#create_plot_and_save_patchwork(db_name, table_name, run_ids(run_dict, model_name, key), None, title_interactive=title(run_dict, model_name, key), show_interactive=True)

# %%
key = '8' #no trafo, 1 controls
create_plot_and_save_patchwork(db_name, table_name, run_ids(run_dict, model_name, key), entropy_strategy_strg=entropy_strategy, loss_function_strg=loss_function, path_to_save= None, title_interactive=title(run_dict, model_name, key, entropy_strategy), show_interactive=True)

# %%
key = '10' #no trafo, 2 controls
create_plot_and_save_patchwork(db_name, table_name, run_ids(run_dict, model_name, key), entropy_strategy_strg=entropy_strategy, loss_function_strg=loss_function, path_to_save= None, title_interactive=title(run_dict, model_name, key, entropy_strategy), show_interactive=True)

# %% [markdown]
# ### Technology Substitution

# %%
db_name = os.path.join(results_dir, 'techsub-model-results.db')
table_name = 'TechnologySubstitution_gamma2' 
path = "./results/TechnologySubstitution/fractionaltrafo3/first_clustering"
with open(OUTPUT_DIR / "techsub-model-run-dict.json", "r") as file:
    run_dict = json.load(file)
entropy_strategy = 'ShannonEntropyAll'
loss_function = 'TransitionEntropyLoss'
model_name = 'TechnologySubstitution'

key = '4'
create_plot_and_save_patchwork(db_name, table_name, run_ids(run_dict, model_name, key), 
                                   entropy_strategy_strg=entropy_strategy, 
                                   loss_function_strg=loss_function, 
                                   #loss_function_coeff=0, 
                                   path_to_save= None, title_interactive=title(run_dict, model_name, key, entropy_strategy), show_interactive=True)
# Out:
# All configurations are the same: True
# Step 0, number of patches: 900, time: 0.00
# Step 100, number of patches: 800, time: 3.05
# Step 200, number of patches: 700, time: 6.45
# Step 300, number of patches: 600, time: 12.75
# Step 400, number of patches: 500, time: 25.92
# Step 500, number of patches: 400, time: 45.60
# Step 600, number of patches: 300, time: 59.41
# Step 700, number of patches: 200, time: 71.37
# Step 800, number of patches: 100, time: 86.07
# No more patches to merge
# Done, after 899 steps
# Launching server at http://localhost:44885
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='edd631da-4711-4f4d-9022-e7861ab95251', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='77a3c91d-6e66-49a3-b783-dd65453a34b9', ...)
# ...

# %%
loss_function = 'TransitionAndSizeEntropyLoss'
create_plot_and_save_patchwork(db_name, table_name, run_ids(run_dict, model_name, key), 
                                   entropy_strategy_strg=entropy_strategy, 
                                   loss_function_strg=loss_function, 
                                   loss_function_coeff=0.15, 
                                   path_to_save= None, title_interactive=title(run_dict, model_name, key, entropy_strategy), show_interactive=True)
# Out:
# All configurations are the same: True
# Step 0, number of patches: 400, time: 0.00
# Step 100, number of patches: 300, time: 3.39
# Step 200, number of patches: 200, time: 13.22
# Step 300, number of patches: 100, time: 24.15
# No more patches to merge
# Done, after 399 steps
# Launching server at http://localhost:38015
# All configurations are the same: True
# Step 0, number of patches: 400, time: 0.00
# Step 100, number of patches: 300, time: 2.07
# Step 200, number of patches: 200, time: 7.15
# Step 300, number of patches: 100, time: 16.23
# No more patches to merge
# Done, after 399 steps
# Launching server at http://localhost:42349
# All configurations are the same: True
# Step 0, number of patches: 400, time: 0.00
# Step 100, number of patches: 300, time: 1.93
# Step 200, number of patches: 200, time: 4.95
# Step 300, number of patches: 100, time: 8.28
# No more patches to merge
# Done, after 399 steps
# Launching server at http://localhost:43847
# ...

# %%
loss_function_coeff = [0.025, 0.05, 0.08, 0.11, 0.15, 0.2, 0.3]

for coeff in loss_function_coeff:
    create_plot_and_save_patchwork(db_name, table_name, run_ids(run_dict, model_name, key), 
                                   entropy_strategy_strg=entropy_strategy, 
                                   loss_function_strg=loss_function, 
                                   loss_function_coeff=coeff, 
                                   path_to_save= None, title_interactive=title(run_dict, model_name, key, entropy_strategy), show_interactive=True)
