# %% [markdown]
# ## Preparation

# %%
import os
import sys
parent_dir = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.append(parent_dir)
from pathlib import Path
import json
import numpy as np
from matplotlib import pyplot as plt

from clustering.patchwork_visualization import create_plot_and_save_patchwork
from patchwork import Patchwork, create_patchwork

# %matplotlib inline

# %%
results_dir = os.path.join(parent_dir, 'datasets', 'results')
OUTPUT_DIR = Path.cwd().parent/ "datasets" / "results"

# %%
run_ids = lambda run_dict, model_name, key: run_dict[model_name][key]['run_ids']
def title(run_dict, model_name, key, entropy_strategy = "ShannonEntropyOnlyMerged"): 
    return f"<h3> {model_name} <br />timestep: {run_dict[model_name][key]['delta_t']} <br /> samples per cell: {run_dict[model_name][key]['num_samples_per_cell']}  <br /> transformation: {run_dict[model_name][key]['transformations']}<br /> Entropy Strategy: {entropy_strategy}</h3>  <br />"

# %% [markdown]
# ## Visualization

# %% [markdown]
# ### Simple Models

# %% [markdown]
# #### SteadyHorizontalFlow

# %%
db_name = os.path.join(results_dir, 'simple-models_results.db')
with open(OUTPUT_DIR / "simple-models_run-dict.json", "r") as file:
    run_dict = json.load(file)

# %%
table_name = 'SteadyHorizontalFlow_c' 
path = "./results/SteadyHorizontalFlow/logistictrafo/first_clustering"
model_name = 'SteadyHorizontalFlow'

# %%
entropy_strategy = 'ShannonEntropyAll'
loss_function = 'TransitionAndSizeEntropyLoss'

# %%
key = '4'
create_plot_and_save_patchwork(db_name, table_name, run_ids(run_dict, model_name, key), entropy_strategy_strg=entropy_strategy, loss_function_strg=loss_function, path_to_save= None, title_interactive=title(run_dict, model_name, key, entropy_strategy), show_interactive=True)
# Out:
# All configurations are the same: True
# Step 0, number of patches: 900, time: 0.00
# Step 100, number of patches: 800, time: 0.81
# Step 200, number of patches: 700, time: 2.07
# Step 300, number of patches: 600, time: 3.04
# Step 400, number of patches: 500, time: 3.86
# Step 500, number of patches: 400, time: 4.62
# Step 600, number of patches: 300, time: 5.22
# Step 700, number of patches: 200, time: 5.86
# Step 800, number of patches: 100, time: 6.23
# No more patches to merge
# Done, after 899 steps
# Launching server at http://localhost:41331
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='89fb3228-6b42-45bc-bdc4-b620852f319d', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='7ee37578-268a-4f4f-ad83-4ead75c7378c', ...)
# WARNING:bokeh.server.views.ws:Failed sending message as connection was closed
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='f6742c76-a335-4427-9b7e-59b0fed87f06', ...)

# %%
table_name = 'TwoStableNodesOneSaddlePoint_c' 
path = "./results/TwoStableNodesOneSaddlePoint/notrafo/first_clustering"
model_name = 'TwoStableNodesOneSaddlePoint'

key = '1'
#entropy_strategy = 'ShannonEntropyOnlyMerged'
#create_plot_and_save_patchwork(db_name, table_name, run_ids(run_dict, model_name, key), entropy_strategy_strg=entropy_strategy, loss_function_strg=loss_function, path_to_save= None, title_interactive=title(run_dict, model_name, key, entropy_strategy), show_interactive=True)

# %%
entropy_strategy = 'ShannonEntropyAll'
create_plot_and_save_patchwork(db_name, table_name, run_ids(run_dict, model_name, key), entropy_strategy_strg=entropy_strategy, loss_function_strg=loss_function, path_to_save= None, title_interactive=title(run_dict, model_name, key, entropy_strategy), show_interactive=True)
# Out:
# All configurations are the same: True
# Percentage of data rows deleted: 0.00%
# Step 0, number of patches: 900, time: 0.00
# Step 100, number of patches: 800, time: 3.37
# Step 200, number of patches: 700, time: 6.46
# Step 300, number of patches: 600, time: 8.63
# Step 400, number of patches: 500, time: 12.10
# Step 500, number of patches: 400, time: 15.08
# Step 600, number of patches: 300, time: 17.27
# Step 700, number of patches: 200, time: 19.08
# Step 800, number of patches: 100, time: 20.61
# No more patches to merge
# Done, after 899 steps
# Launching server at http://localhost:34141
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='69323dca-403b-4cf1-bdca-a3cfc233560a', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='9c8e0f8b-79dd-444e-9f24-b64abb0e5263', ...)
# WARNING:bokeh.server.views.ws:Failed sending message as connection was closed
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='d887caaa-0783-431b-8b47-b58fbec07089', ...)
# WARNING:root:Dropping a patch because it contains a previously known reference (id='419842bf-2ac8-48f7-a729-aaa64605a229'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='412839de-82af-45ee-98f8-a1b036118039'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='85944ac0-0ade-4c56-ae9e-5ba3bbd31d4d'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='
'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='8d8d1eb0-3cdd-4459-bead-9d2f974a5aa1'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='c024865b-27bd-4aa6-8ff0-b8a1684cf81d'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='631d17b9-b600-4b8c-bebd-6fe88183a812'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='3e6bd58b-ec92-41a8-8742-5ecdea99ab1c'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.

# %%
table_name = 'StableNode_c' 
path = "./results/StableNode/notrafo/first_clustering"
model_name = 'StableNode'


key = '1'
#entropy_strategy = 'ShannonEntropyOnlyMerged'
#create_plot_and_save_patchwork(db_name, table_name, run_ids(run_dict, model_name, key), entropy_strategy_strg=entropy_strategy, loss_function_strg=loss_function, path_to_save= None, title_interactive=title(run_dict, model_name, key, entropy_strategy), show_interactive=True)

# %%
entropy_strategy = 'ShannonEntropyAll'
create_plot_and_save_patchwork(db_name, table_name, run_ids(run_dict, model_name, key), entropy_strategy_strg=entropy_strategy, loss_function_strg=loss_function, path_to_save= None, title_interactive=title(run_dict, model_name, key, entropy_strategy), show_interactive=True)
# Out:
# All configurations are the same: True
# Percentage of data rows deleted: 0.00%
# Step 0, number of patches: 900, time: 0.00
# Step 100, number of patches: 800, time: 1.40
# Step 200, number of patches: 700, time: 3.05
# Step 300, number of patches: 600, time: 4.40
# Step 400, number of patches: 500, time: 5.60
# Step 500, number of patches: 400, time: 6.76
# Step 600, number of patches: 300, time: 7.90
# Step 700, number of patches: 200, time: 8.90
# Step 800, number of patches: 100, time: 9.97
# No more patches to merge
# Done, after 899 steps
# Launching server at http://localhost:40593
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='c14ebbf4-9536-49a0-814d-055e788c7660', ...)

# %% [markdown]
# ### FitzHugh-Nagumo Model

# %%
db_name = os.path.join(results_dir, 'fhn-model-results.db')

table_name = 'FitzHughNagumoModel_b_I' 
path = "./results/FitzHugh-Nagumo_Model/logistictrafo"
with open(OUTPUT_DIR / "fhn-model-run-dict.json", "r") as file:
    run_dict = json.load(file)

#fhn_run_ids = lambda key: run_dict['FitzHughNagumoModel'][key]['run_ids']
#fhn_title = lambda key: f"<h3> FitzHugh-Nagumo Model  <br />timestep: {run_dict['FitzHughNagumoModel'][key]['delta_t']} <br /> samples per cell: {run_dict['FitzHughNagumoModel'][key]['num_samples_per_cell']} </h3>  <br />"

model_name = 'FitzHughNagumoModel'

# %%
key = '1' #logistic trafo, 2 controls
create_plot_and_save_patchwork(db_name, table_name, run_ids(run_dict, model_name, key), None, title_interactive=title(run_dict, model_name, key), show_interactive=True)
# Out:
# All configurations are the same: True
# Step 0, number of patches: 900, time: 0.00
# Step 100, number of patches: 800, time: 2.69
# Step 200, number of patches: 700, time: 5.93
# Step 300, number of patches: 600, time: 9.78
# Step 400, number of patches: 500, time: 13.96
# Step 500, number of patches: 400, time: 16.24
# Step 600, number of patches: 300, time: 19.29
# Step 700, number of patches: 200, time: 23.58
# Step 800, number of patches: 100, time: 27.73
# No more patches to merge
# Done, after 899 steps
# Launching server at http://localhost:35269

# %%
key = '5' #logistic trafo, 1 controls
create_plot_and_save_patchwork(db_name, table_name, run_ids(run_dict, model_name, key), entropy_strategy_strg='ShannonEntropyAll', path_to_save=None, title_interactive=title(run_dict, model_name, key), show_interactive=True)
# Out:
# All configurations are the same: True
# Step 0, number of patches: 900, time: 0.00
# Step 100, number of patches: 800, time: 3.49
# Step 200, number of patches: 700, time: 8.18
# Step 300, number of patches: 600, time: 13.26
# Step 400, number of patches: 500, time: 18.64
# Step 500, number of patches: 400, time: 24.18
# Step 600, number of patches: 300, time: 29.06

# %%
key = '7' #no trafo, 1 controls
#create_plot_and_save_patchwork(db_name, table_name, run_ids(run_dict, model_name, key), None, title_interactive=title(run_dict, model_name, key), show_interactive=True)
# Out:
# All configurations are the same: True
# Percentage of data rows deleted: 0.00%
# No more patches to merge
# Done, after 899 steps
# Launching server at http://localhost:36265
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='b091fd98-81bb-4027-9996-ce3c4565a43e', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='423260c3-51a0-4642-bbad-2e1e851779e2', ...)

# %%
key = '8' #no trafo, 1 controls
create_plot_and_save_patchwork(db_name, table_name, run_ids(run_dict, model_name, key), None, title_interactive=title(run_dict, model_name, key), show_interactive=True)
# Out:
# All configurations are the same: True
# Percentage of data rows deleted: 0.00%
# Step 0, number of patches: 900, time: 0.00
# Step 100, number of patches: 800, time: 1.60
# Step 200, number of patches: 700, time: 2.46
# Step 300, number of patches: 600, time: 3.42
# Step 400, number of patches: 500, time: 4.56
# Step 500, number of patches: 400, time: 5.59
# Step 600, number of patches: 300, time: 6.63
# Step 700, number of patches: 200, time: 7.58
# Step 800, number of patches: 100, time: 8.42
# No more patches to merge
# Done, after 899 steps
# Launching server at http://localhost:44949
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='e078f37a-4916-4c71-9625-d37ebf78f410', ...)

# %%
key = '10' #no trafo, 2 controls
create_plot_and_save_patchwork(db_name, table_name, run_ids(run_dict, model_name, key), None, title_interactive=title(run_dict, model_name, key), show_interactive=True)
# Out:
# All configurations are the same: True
# Percentage of data rows deleted: 0.00%
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 2
#       1 key = '10' #no trafo, 2 controls
# ----> 2 create_plot_and_save_patchwork(db_name, table_name, run_ids(run_dict, model_name, key), None, title_interactive=title(run_dict, model_name, key), show_interactive=True)
#
# File ~/masterthesis/Coding/mdp-world-model/clustering/patchwork_visualization.py:342, in create_plot_and_save_patchwork(db_name, table_name, run_ids, path_to_save, gif_steps, title_interactive, show_interactive)
#     339         os.makedirs(path_id)
#     340     path_to_save = path_id + f"/firstPatchwork_{str(gif_steps)}stepsPerTime"
# --> 342 patchwork, controls, solver = create_patchwork(db_name, table_name, run_ids)
#     344 fig, ax = plt.subplots(figsize=(7, 6))
#     345 plot_2D_vector_field_over_grid(patchwork.grid, solver, control=controls[0], ax=ax, display_vectorfield=True, resolution = 21)
#
# File ~/masterthesis/Coding/mdp-world-model/clustering/patchwork.py:472, in create_patchwork(db_name, table_name, run_ids)
#     470     print(f"Percentage of data rows deleted: {rows_to_delete_percentage:.2f}%")
#     471     df = df[df['y'].apply(lambda y: max(y) <= grid.bounds[0][-1])] #as we run out of the defined space
# --> 472     patchwork = Patchwork(grid,df)
#     473 else:
#     474     patchwork = Patchwork(grid, df)
#
# File ~/masterthesis/Coding/mdp-world-model/clustering/patchwork.py:42, in Patchwork.__init__(self, grid, df, entropy_strategy)
#      39 self.patch_relevances = self._init_uniform_patch_relevances()                           #Dict
#      41 self.predecessors = self._init_predecessors()                                           #Dict
# ---> 42 self.entropy_dict = self._init_entropy_dict()                                           #Dict
#      43 self.adjacent_cells_losses = self._init_adjacent_cells_losses()
#
# File ~/masterthesis/Coding/mdp-world-model/clustering/patchwork.py:108, in Patchwork._init_entropy_dict(self)
#     102 def _init_entropy_dict(self):
#     103     """
#     104     Initializes a dictionary with the entropy of each patch.
#     105     The dictionary is nested: entropy_dict[s][a] = entropy of the probability distribution of action a in patch s.
#     106     Moreover, there is an additional key 'avg' for the average entropy of all actions in patch s.
#     107     """
# --> 108     return self.entropy_strategy.init_entropy_dict(self)
#
# AttributeError: type object 'ShannonEntropyOnlyMerged' has no attribute 'init_entropy_dict'

# %% [markdown]
# ### Technology Substitution

# %%
db_name = os.path.join(results_dir, 'simulation_results.db')
table_name = 'TechnologySubstitution_gamma2' 
path = "./results/TechnologySubstitution/fractionaltrafo3/first_clustering"
with open(OUTPUT_DIR / "run_dict.json", "r") as file:
    run_dict = json.load(file)
tech_run_ids = lambda key: run_dict['TechSub'][key]['run_ids']
tech_title = lambda key: f"<h3> Technology Substitution  <br />timestep: {run_dict['TechSub'][key]['delta_t']} <br /> samples per cell: {run_dict['TechSub'][key]['num_samples_per_cell']} </h3>  <br />"


key = '6'
create_plot_and_save_patchwork(db_name, table_name, tech_run_ids(key), None, title_interactive=tech_title(key), show_interactive=True)
# Out:
# All configurations are the same: True
# No more patches to merge
# Done, after 399 steps
# Launching server at http://localhost:35619
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='5dabb4e2-1f9f-417b-9ec2-83af387229b7', ...)
# WARNING:root:Dropping a patch because it contains a previously known reference (id='7e9c7097-46dd-48a9-8c89-82a8412621df'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='81d27138-1a1f-4daa-878f-86a4c2fadf33'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
