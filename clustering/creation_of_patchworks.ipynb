# %% [markdown]
# ## Preparation

# %%
import os
import sys
parent_dir = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.append(parent_dir)
from pathlib import Path
import json
import numpy as np
from matplotlib import pyplot as plt

from clustering.patchwork_visualization import create_plot_and_save_patchwork
from patchwork import Patchwork, create_patchwork

# %matplotlib inline
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='46a6816b-9fc9-4b63-b6db-94145e9bf2b0'>
#   <div id="a6378a6b-038d-483c-b778-688cae496043" data-root-id="46a6816b-9fc9-4b63-b6db-94145e9bf2b0" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
results_dir = os.path.join(parent_dir, 'datasets', 'results')
OUTPUT_DIR = Path.cwd().parent/ "datasets" / "results"

# %%
run_ids = lambda run_dict, model_name, key: run_dict[model_name][key]['run_ids']
def title(run_dict, model_name, key, entropy_strategy = "ShannonEntropyOnlyMerged"): 
    return f"<h3> {model_name} <br />timestep: {run_dict[model_name][key]['delta_t']} <br /> samples per cell: {run_dict[model_name][key]['num_samples_per_cell']}  <br /> transformation: {run_dict[model_name][key]['transformations']}<br /> Entropy Strategy: {entropy_strategy}</h3>  <br />"

# %% [markdown]
# ## Visualization

# %% [markdown]
# ### FitzHugh-Nagumo Model

# %%
db_name = os.path.join(results_dir, 'fhn-model-results.db')

table_name = 'FitzHughNagumoModel_b_I' 
path = "./results/FitzHugh-Nagumo_Model/logistictrafo"
with open(OUTPUT_DIR / "fhn-model-run-dict.json", "r") as file:
    run_dict = json.load(file)

#fhn_run_ids = lambda key: run_dict['FitzHughNagumoModel'][key]['run_ids']
#fhn_title = lambda key: f"<h3> FitzHugh-Nagumo Model  <br />timestep: {run_dict['FitzHughNagumoModel'][key]['delta_t']} <br /> samples per cell: {run_dict['FitzHughNagumoModel'][key]['num_samples_per_cell']} </h3>  <br />"

model_name = 'FitzHughNagumoModel'

# %%
key = '1' #logistic trafo, 2 controls
create_plot_and_save_patchwork(db_name, table_name, run_ids(run_dict, model_name, key), None, title_interactive=title(run_dict, model_name, key), show_interactive=True)
# Out:
# All configurations are the same: True
# Step 0, number of patches: 900, time: 0.00
# Step 100, number of patches: 800, time: 2.66
# Step 200, number of patches: 700, time: 5.78
# Step 300, number of patches: 600, time: 9.56
# Step 400, number of patches: 500, time: 14.13
# Step 500, number of patches: 400, time: 16.76
# Step 600, number of patches: 300, time: 19.90
# Step 700, number of patches: 200, time: 24.01
# Step 800, number of patches: 100, time: 29.26
# No more patches to merge
# Done, after 899 steps
# Launching server at http://localhost:33619
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='60562c8f-e3ac-4edb-93fa-76ed4002b6aa', ...)

# %%
key = '5' #logistic trafo, 1 controls
create_plot_and_save_patchwork(db_name, table_name, run_ids(run_dict, model_name, key), entropy_strategy_strg='ShannonEntropyAll', path_to_save=None, title_interactive=title(run_dict, model_name, key), show_interactive=True)
# Out:
# All configurations are the same: True
# Step 0, number of patches: 900, time: 0.00
# Step 100, number of patches: 800, time: 3.24
# Step 200, number of patches: 700, time: 7.33
# Step 300, number of patches: 600, time: 11.84
# Step 400, number of patches: 500, time: 16.73
# Step 500, number of patches: 400, time: 22.14
# Step 600, number of patches: 300, time: 26.69
# Step 700, number of patches: 200, time: 31.54
# Step 800, number of patches: 100, time: 37.11
# No more patches to merge
# Done, after 899 steps
# Launching server at http://localhost:39263
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='a15468ab-c7c5-4514-9ccc-03c8bdd76535', ...)

# %%
key = '7' #no trafo, 1 controls
#create_plot_and_save_patchwork(db_name, table_name, run_ids(run_dict, model_name, key), None, title_interactive=title(run_dict, model_name, key), show_interactive=True)
# Out:
# All configurations are the same: True
# Percentage of data rows deleted: 0.00%
# No more patches to merge
# Done, after 899 steps
# Launching server at http://localhost:36265
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='b091fd98-81bb-4027-9996-ce3c4565a43e', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='423260c3-51a0-4642-bbad-2e1e851779e2', ...)

# %%
key = '8' #no trafo, 1 controls
create_plot_and_save_patchwork(db_name, table_name, run_ids(run_dict, model_name, key), None, title_interactive=title(run_dict, model_name, key), show_interactive=True)
# Out:
# All configurations are the same: True
# Percentage of data rows deleted: 0.00%
# Step 0, number of patches: 900, time: 0.00
# Step 100, number of patches: 800, time: 1.60
# Step 200, number of patches: 700, time: 2.46
# Step 300, number of patches: 600, time: 3.42
# Step 400, number of patches: 500, time: 4.56
# Step 500, number of patches: 400, time: 5.59
# Step 600, number of patches: 300, time: 6.63
# Step 700, number of patches: 200, time: 7.58
# Step 800, number of patches: 100, time: 8.42
# No more patches to merge
# Done, after 899 steps
# Launching server at http://localhost:44949
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='e078f37a-4916-4c71-9625-d37ebf78f410', ...)

# %%
key = '10' #no trafo, 2 controls
create_plot_and_save_patchwork(db_name, table_name, run_ids(run_dict, model_name, key), None, title_interactive=title(run_dict, model_name, key), show_interactive=True)
# Out:
# All configurations are the same: True
# Percentage of data rows deleted: 0.00%
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 2
#       1 key = '10' #no trafo, 2 controls
# ----> 2 create_plot_and_save_patchwork(db_name, table_name, run_ids(run_dict, model_name, key), None, title_interactive=title(run_dict, model_name, key), show_interactive=True)
#
# File ~/masterthesis/Coding/mdp-world-model/clustering/patchwork_visualization.py:342, in create_plot_and_save_patchwork(db_name, table_name, run_ids, path_to_save, gif_steps, title_interactive, show_interactive)
#     339         os.makedirs(path_id)
#     340     path_to_save = path_id + f"/firstPatchwork_{str(gif_steps)}stepsPerTime"
# --> 342 patchwork, controls, solver = create_patchwork(db_name, table_name, run_ids)
#     344 fig, ax = plt.subplots(figsize=(7, 6))
# ...

# %% [markdown]
# ### Technology Substitution

# %%
db_name = os.path.join(results_dir, 'simulation_results.db')
table_name = 'TechnologySubstitution_gamma2' 
path = "./results/TechnologySubstitution/fractionaltrafo3/first_clustering"
with open(OUTPUT_DIR / "run_dict.json", "r") as file:
    run_dict = json.load(file)
tech_run_ids = lambda key: run_dict['TechSub'][key]['run_ids']
tech_title = lambda key: f"<h3> Technology Substitution  <br />timestep: {run_dict['TechSub'][key]['delta_t']} <br /> samples per cell: {run_dict['TechSub'][key]['num_samples_per_cell']} </h3>  <br />"


key = '6'
create_plot_and_save_patchwork(db_name, table_name, tech_run_ids(key), None, title_interactive=tech_title(key), show_interactive=True)
# Out:
# All configurations are the same: True
# No more patches to merge
# Done, after 399 steps
# Launching server at http://localhost:35619
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='5dabb4e2-1f9f-417b-9ec2-83af387229b7', ...)
# WARNING:root:Dropping a patch because it contains a previously known reference (id='7e9c7097-46dd-48a9-8c89-82a8412621df'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='81d27138-1a1f-4daa-878f-86a4c2fadf33'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.

# %% [markdown]
# ### Simple Models

# %% [markdown]
# #### SteadyHorizontalFlow

# %%
db_name = os.path.join(results_dir, 'simple-models_results.db')
with open(OUTPUT_DIR / "simple-models_run-dict.json", "r") as file:
    run_dict = json.load(file)

# %%
table_name = 'SteadyHorizontalFlow_c' 
path = "./results/SteadyHorizontalFlow/logistictrafo/first_clustering"
model_name = 'SteadyHorizontalFlow'

# %%
key = '4'
entropy_strategy = 'ShannonEntropyAll'
patchwork, _, _ = create_patchwork(db_name, table_name, run_ids(run_dict, model_name, key), entropy_strategy_strg=entropy_strategy)
# Out:
# All configurations are the same: True

# %%
patchwork.step()
# Out:
# True

# %%
patchwork.test_adjacent_cells_losses(tol =  1e-15)
# Out:
# True

# %%
key = '4'
entropy_strategy = 'ShannonEntropyOnlyMerged'
create_plot_and_save_patchwork(db_name, table_name, run_ids(run_dict, model_name, key), entropy_strategy_strg=entropy_strategy, path_to_save= None, title_interactive=title(run_dict, model_name, key, entropy_strategy), show_interactive=True)
# Out:
# All configurations are the same: True
# Step 0, number of patches: 900, time: 0.00
# Step 100, number of patches: 800, time: 1.05
# Step 200, number of patches: 700, time: 1.76
# Step 300, number of patches: 600, time: 2.54
# Step 400, number of patches: 500, time: 3.54
# Step 500, number of patches: 400, time: 4.57
# Step 600, number of patches: 300, time: 5.38
# Step 700, number of patches: 200, time: 5.84
# Step 800, number of patches: 100, time: 6.20
# No more patches to merge
# Done, after 899 steps
# Launching server at http://localhost:40137
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='76a75fc6-6b85-4743-a7e1-2d575169d1fb', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='baa3343d-b848-476d-8a31-c908719c0b83', ...)
# WARNING:bokeh.server.views.ws:Failed sending message as connection was closed
# ...

# %%
entropy_strategy = 'ShannonEntropyAll'
create_plot_and_save_patchwork(db_name, table_name, run_ids(run_dict, model_name, key), entropy_strategy_strg=entropy_strategy, path_to_save= None, title_interactive=title(run_dict, model_name, key, entropy_strategy), show_interactive=True)
# Out:
# All configurations are the same: True
# Step 0, number of patches: 900, time: 0.00
# Step 100, number of patches: 800, time: 1.04
# Step 200, number of patches: 700, time: 1.76
# Step 300, number of patches: 600, time: 2.84
# Step 400, number of patches: 500, time: 3.99
# Step 500, number of patches: 400, time: 5.50
# Step 600, number of patches: 300, time: 6.27
# Step 700, number of patches: 200, time: 6.95
# Step 800, number of patches: 100, time: 7.36
# No more patches to merge
# Done, after 899 steps
# Launching server at http://localhost:41445
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='f74c3978-6691-4297-a4fc-1b6ae49e8921', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='ff3f0106-648d-4879-b16e-dbb82e114114', ...)
# WARNING:bokeh.server.views.ws:Failed sending message as connection was closed
# ...

# %%
table_name = 'TwoStableNodesOneSaddlePoint_c' 
path = "./results/TwoStableNodesOneSaddlePoint/notrafo/first_clustering"
model_name = 'TwoStableNodesOneSaddlePoint'


key = '1'
entropy_strategy = 'ShannonEntropyOnlyMerged'
create_plot_and_save_patchwork(db_name, table_name, run_ids(run_dict, model_name, key), entropy_strategy_strg=entropy_strategy, path_to_save= None, title_interactive=title(run_dict, model_name, key, entropy_strategy), show_interactive=True)
# Out:
# All configurations are the same: True
# Percentage of data rows deleted: 0.00%
# Step 0, number of patches: 900, time: 0.00
# Step 100, number of patches: 800, time: 2.09
# Step 200, number of patches: 700, time: 4.42
# Step 300, number of patches: 600, time: 6.20
# Step 400, number of patches: 500, time: 8.82
# Step 500, number of patches: 400, time: 12.31
# Step 600, number of patches: 300, time: 15.05
# Step 700, number of patches: 200, time: 16.18
# Step 800, number of patches: 100, time: 17.13
# No more patches to merge
# Done, after 899 steps
# Launching server at http://localhost:38929
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='5e227956-cacc-49b4-9ab9-3750f84c319a', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='a83c470c-230f-432d-b036-27eca4db3028', ...)
# ...

# %%
entropy_strategy = 'ShannonEntropyAll'
create_plot_and_save_patchwork(db_name, table_name, run_ids(run_dict, model_name, key), entropy_strategy_strg=entropy_strategy, path_to_save= None, title_interactive=title(run_dict, model_name, key, entropy_strategy), show_interactive=True)
# Out:
# All configurations are the same: True
# Percentage of data rows deleted: 0.00%
# Step 0, number of patches: 900, time: 0.00
# Step 100, number of patches: 800, time: 4.53
# Step 200, number of patches: 700, time: 9.74
# Step 300, number of patches: 600, time: 16.56
# Step 400, number of patches: 500, time: 23.05
# Step 500, number of patches: 400, time: 30.07
# Step 600, number of patches: 300, time: 33.19
# Step 700, number of patches: 200, time: 34.79
# Step 800, number of patches: 100, time: 36.19
# No more patches to merge
# Done, after 899 steps
# Launching server at http://localhost:45859
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='084814cf-167f-4770-8c3f-e5de8c40826e', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='cb97c9a1-506a-4942-8963-7aa5d35784f6', ...)
# ...

# %%
key = '2'
entropy_strategy = 'ShannonEntropyOnlyMerged'
create_plot_and_save_patchwork(db_name, table_name, run_ids(run_dict, model_name, key), entropy_strategy_strg=entropy_strategy, path_to_save= None, title_interactive=title(run_dict, model_name, key, entropy_strategy), show_interactive=True)
# Out:
# All configurations are the same: True
# Percentage of data rows deleted: 0.00%
# Step 0, number of patches: 900, time: 0.00
# Step 100, number of patches: 800, time: 0.92
# Step 200, number of patches: 700, time: 1.88
# Step 300, number of patches: 600, time: 3.30
# Step 400, number of patches: 500, time: 4.32
# Step 500, number of patches: 400, time: 5.41
# Step 600, number of patches: 300, time: 6.62
# Step 700, number of patches: 200, time: 7.33
# Step 800, number of patches: 100, time: 7.84
# No more patches to merge
# Done, after 899 steps
# Launching server at http://localhost:40199
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='f8d78a32-bbfd-4583-a19b-32bce10e6541', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='d78f7297-e564-4b6b-8612-9a1cb6d55c3b', ...)

# %%
entropy_strategy = 'ShannonEntropyAll'
create_plot_and_save_patchwork(db_name, table_name, run_ids(run_dict, model_name, key), entropy_strategy_strg=entropy_strategy, path_to_save= None, title_interactive=title(run_dict, model_name, key, entropy_strategy), show_interactive=True)
# Out:
# All configurations are the same: True
# Percentage of data rows deleted: 0.00%
# Step 0, number of patches: 900, time: 0.00
# Step 100, number of patches: 800, time: 2.01
# Step 200, number of patches: 700, time: 4.48
# Step 300, number of patches: 600, time: 6.67
# Step 400, number of patches: 500, time: 9.17
# Step 500, number of patches: 400, time: 11.37
# Step 600, number of patches: 300, time: 12.78
# Step 700, number of patches: 200, time: 13.64
# Step 800, number of patches: 100, time: 14.36
# No more patches to merge
# Done, after 899 steps
# Launching server at http://localhost:33803
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='b5423e66-5c2c-4feb-97ce-0ecbdcea8d7d', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='86ec1ae9-2848-463e-bcbb-01cfcca31e10', ...)

# %%
table_name = 'StableNode_c' 
path = "./results/StableNode/notrafo/first_clustering"
model_name = 'StableNode'


key = '1'
entropy_strategy = 'ShannonEntropyOnlyMerged'
create_plot_and_save_patchwork(db_name, table_name, run_ids(run_dict, model_name, key), entropy_strategy_strg=entropy_strategy, path_to_save= None, title_interactive=title(run_dict, model_name, key, entropy_strategy), show_interactive=True)
# Out:
# All configurations are the same: True
# Percentage of data rows deleted: 0.00%
# Step 0, number of patches: 900, time: 0.00
# Step 100, number of patches: 800, time: 0.86
# Step 200, number of patches: 700, time: 1.68
# Step 300, number of patches: 600, time: 2.91
# Step 400, number of patches: 500, time: 4.05
# Step 500, number of patches: 400, time: 5.02
# Step 600, number of patches: 300, time: 5.97
# Step 700, number of patches: 200, time: 6.87
# Step 800, number of patches: 100, time: 7.74
# No more patches to merge
# Done, after 899 steps
# Launching server at http://localhost:33365
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='76a68612-efc0-41ab-ae66-5a38d2d7a70d', ...)
# ...

# %%
entropy_strategy = 'ShannonEntropyAll'
create_plot_and_save_patchwork(db_name, table_name, run_ids(run_dict, model_name, key), entropy_strategy_strg=entropy_strategy, path_to_save= None, title_interactive=title(run_dict, model_name, key, entropy_strategy), show_interactive=True)
# Out:
# All configurations are the same: True
# Percentage of data rows deleted: 0.00%
# Step 0, number of patches: 900, time: 0.00
# Step 100, number of patches: 800, time: 1.44
# Step 200, number of patches: 700, time: 4.12
# Step 300, number of patches: 600, time: 5.95
# Step 400, number of patches: 500, time: 8.47
# Step 500, number of patches: 400, time: 10.43
# Step 600, number of patches: 300, time: 12.54
# Step 700, number of patches: 200, time: 14.25
# Step 800, number of patches: 100, time: 16.74
# No more patches to merge
# Done, after 899 steps
# Launching server at http://localhost:42737
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='846a6c7d-2ed4-4f30-8e69-694fb9f7ab2e', ...)
# ...
