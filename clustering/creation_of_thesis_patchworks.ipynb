# %% [markdown]
# ## Preparation

# %%
import os
import sys
parent_dir = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.append(parent_dir)
from pathlib import Path
import json
import numpy as np
from matplotlib import pyplot as plt
from scipy.spatial import Voronoi, voronoi_plot_2d

from clustering.patchwork_visualization import create_plot_and_save_patchwork
from patchwork import Patchwork, create_patchwork
from datasets.data_reconstruction import get_and_reconstruct_data, reconstruct_solver_and_grid

# %matplotlib inline
results_dir = os.path.join(parent_dir, 'datasets', 'results')
OUTPUT_DIR = Path.cwd().parent/ "datasets" / "results" 
run_ids = lambda run_dict, model_name, key: run_dict[model_name][key]['run_ids']
def title(run_dict, model_name, key, entropy_strategy = "ShannonEntropyOnlyMerged", entropy_measure = 'shannon_entropy'): 
    return f"<h3> {model_name} <br />timestep: {run_dict[model_name][key]['delta_t']} <br /> samples per cell: {run_dict[model_name][key]['num_samples_per_cell']}  <br /> transformation: {run_dict[model_name][key]['transformations']}<br />  Entropy Measure: {entropy_measure}</h3>  <br />"
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='2ddaa519-945a-4f62-bce1-f891ed447f6e'>
#   <div id="a9dfcd64-ebf5-4d3f-8650-b3f4026babc1" data-root-id="2ddaa519-945a-4f62-bce1-f891ed447f6e" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"e0f2e98b-67e1-45de-8477-eb0de6baec82":{"version":"3.6.2","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"2ddaa519-945a-4f62-bce1-f891ed447f6e"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"d7b072b4-ddb0-4639-a0a8-830f98ffa10f","attributes":{"plot_id":"2ddaa519-945a-4f62-bce1-f891ed447f6e","comm_id":"e53f3d4f4f334eeb903691b00a3e59bb","client_comm_id":"8f366728dd7e4fe89e82c54710f8ceab"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_rendered","kind":"Any","default":false},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","d ...
#   var render_items = [{"docid":"e0f2e98b-67e1-45de-8477-eb0de6baec82","roots":{"2ddaa519-945a-4f62-bce1-f891ed447f6e":"a9dfcd64-ebf5-4d3f-8650-b3f4026babc1"},"root_ids":["2ddaa519-945a-4f62-bce1-f891ed447f6e"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>

# %% [markdown]
# ## Visualization

# %% [markdown]
# ## 4.2 Preliminary Results

# %% [markdown]
# ### Fig. 4.3 Uniform Flow

# %%
db_name = os.path.join(results_dir, 'simple-models_thesis_results.db')
with open(OUTPUT_DIR / "simple-models_thesis_run-dict.json", "r") as file:
    run_dict = json.load(file)
entropy_strategy = 'ShannonEntropyAll' 
loss_function = 'TransitionEntropyLoss' #'TransitionEntropyLoss' #'TransitionAndSizeEntropyLoss'
entropy_measure = 'shannon_entropy'

# %%
table_name = 'UniformFlow_c' 
#path = "./results/thesis/4-2_preliminary_results/uniform_flow"
model_name = 'UniformFlow'
key = '1'
create_plot_and_save_patchwork(db_name, table_name, run_ids(run_dict, model_name, key), 
                                   entropy_strategy_strg=entropy_strategy, 
                                   entropy_measure = entropy_measure,
                                   loss_function_strg=loss_function, 
                                   #path_to_save= path, 
                                   title_interactive=title(run_dict, model_name, key, entropy_strategy), 
                                   show_interactive=True)
# Out:
# All configurations are the same: True
# Percentage of data rows deleted: 2.00%
# Step 0, number of patches: 900, time: 0.00
# Step 100, number of patches: 800, time: 1.36
# Step 200, number of patches: 700, time: 3.08
# Step 300, number of patches: 600, time: 4.94
# Step 400, number of patches: 500, time: 7.02
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 5
#       3 model_name = 'UniformFlow'
#       4 key = '1'
# ----> 5 create_plot_and_save_patchwork(db_name, table_name, run_ids(run_dict, model_name, key),
#       6                                    entropy_strategy_strg=entropy_strategy,
#       7                                    entropy_measure = entropy_measure,
#       8                                    loss_function_strg=loss_function,
#       9                                    #path_to_save= path,
#      10                                    title_interactive=title(run_dict, model_name, key, entropy_strategy),
#      11                                    show_interactive=True)
#
# File ~/masterthesis/Coding/mdp-world-model/clustering/patchwork_visualization.py:712, in create_plot_and_save_patchwork(db_name, table_name, run_ids, path_to_save, gif_steps, title_interactive, show_interactive, entropy_strategy_strg, entropy_measure, loss_function_strg, size_loss_function_strg, loss_function_coeff)
#     709     plot_entropy_overlay(ax, patchwork, cmap='viridis', alpha=0.5)
#     710     fig.savefig(path_id + "/StartEntropy.png")
# --> 712 patchwork.run()
#     713 plot_interactive_patchwork(patchwork, controls, solver, title_interactive, save_to_path=path_to_save, save_steps = gif_steps, show_interactive=show_interactive)
#
# File ~/masterthesis/Coding/mdp-world-model/clustering/patchwork.py:313, in Patchwork.run(self, n_steps)
#     311 if step % 100 == 0:
#     312     print(f"Step {step}, number of patches: {len(self.current_patches)}, time: {time.time() - start_time:.2f}")
# --> 313 if not self.step():
#     314     print(f"Done, after {step} steps")
#     315     break
#
# File ~/masterthesis/Coding/mdp-world-model/clustering/patchwork.py:296, in Patchwork.step(self)
#     293 newpatch = self.current_patches[-1] + 1
#     294 self.current_patches.append(newpatch)
# --> 296 self.merge_adjacent_patches(patch1, patch2, newpatch)
#     298 self.current_patches.remove(patch1)
#     299 self.current_patches.remove(patch2)
#
# File ~/masterthesis/Coding/mdp-world-model/clustering/patchwork.py:269, in Patchwork.merge_adjacent_patches(self, patch1, patch2, newpatch)
#     266 self._update_entropy_dict(patch1, patch2, newpatch, merged_entropy_dict)
#     267 patch1_rel, patch2_rel = self._update_patch_relevances(patch1, patch2, newpatch)
# --> 269 old_predecessors = self._update_predecessors(patch1, patch2, newpatch)
#     270 self._update_patch_neighbors(patch1, patch2, newpatch)
#     271 self._update_adjacent_cells_delta_losses(patch1, patch2, newpatch, old_predecessors)
#
# File ~/masterthesis/Coding/mdp-world-model/clustering/patchwork.py:377, in Patchwork._update_predecessors(self, patch1, patch2, newpatch)
#     369 def _update_predecessors(self, patch1, patch2, newpatch):
#     370     """
#     371     Updates the predecessors dictionary for merging patch1 and patch2 into newpatch.
#     372     The predecessors of newpatch are the union of the predecessors of patch1 and patch2.
#     373     Additionally, the predecessors-set of all patches where patch1 or patch2 are predecessors is updated by replacing patch1 or/and patch2 with newpatch.
#     374     The predecessors of patch1 and patch2 are removed from the dictionary.
#     375     """
# --> 377     old_predecessors = copy.deepcopy(self.predecessors)
#     379     # Update all predecessors of newpatch (prior predecessors of patch1 and patch2)
#     380     self.predecessors[newpatch] = dict()
#
# File ~/anaconda3/envs/py312clustering/lib/python3.12/copy.py:136, in deepcopy(x, memo, _nil)
#     134 copier = _deepcopy_dispatch.get(cls)
#     135 if copier is not None:
# --> 136     y = copier(x, memo)
#     137 else:
#     138     if issubclass(cls, type):
#
# File ~/anaconda3/envs/py312clustering/lib/python3.12/copy.py:221, in _deepcopy_dict(x, memo, deepcopy)
#     219 memo[id(x)] = y
#     220 for key, value in x.items():
# --> 221     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     222 return y
#
# File ~/anaconda3/envs/py312clustering/lib/python3.12/copy.py:136, in deepcopy(x, memo, _nil)
#     134 copier = _deepcopy_dispatch.get(cls)
#     135 if copier is not None:
# --> 136     y = copier(x, memo)
#     137 else:
#     138     if issubclass(cls, type):
#
# File ~/anaconda3/envs/py312clustering/lib/python3.12/copy.py:221, in _deepcopy_dict(x, memo, deepcopy)
#     219 memo[id(x)] = y
#     220 for key, value in x.items():
# --> 221     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     222 return y
#
# File ~/anaconda3/envs/py312clustering/lib/python3.12/copy.py:151, in deepcopy(x, memo, _nil)
#     149 reductor = getattr(x, "__reduce_ex__", None)
#     150 if reductor is not None:
# --> 151     rv = reductor(4)
#     152 else:
#     153     reductor = getattr(x, "__reduce__", None)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Fig. 4.4 Stable Node

# %%
table_name = 'StableNode_c' 
path = "./results/thesis/4-2_preliminary_results/stable_node"
model_name = 'StableNode'

key = '1' 
create_plot_and_save_patchwork(db_name, table_name, run_ids(run_dict, model_name, key), 
                                entropy_strategy_strg=entropy_strategy, 
                                entropy_measure = entropy_measure,
                                loss_function_strg=loss_function, 
                                #path_to_save=path, 
                                title_interactive=title(run_dict, model_name, key, entropy_strategy, entropy_measure), show_interactive=True)
# Out:
# All configurations are the same: True
# Percentage of data rows deleted: 0.00%
# Step 0, number of patches: 900, time: 0.00
# Step 100, number of patches: 800, time: 2.28
# Step 200, number of patches: 700, time: 4.42
# Step 300, number of patches: 600, time: 7.64
# Step 400, number of patches: 500, time: 10.68
# Step 500, number of patches: 400, time: 14.51
# Step 600, number of patches: 300, time: 16.89
# Step 700, number of patches: 200, time: 19.12
# Step 800, number of patches: 100, time: 22.30
# No more patches to merge
# Done, after 899 steps
# Launching server at http://localhost:35275
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='ee2d9c57-e7ca-4135-9101-8328aa098e5c', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='cef6d60c-5555-47af-a44e-1ad9eddfc0cf', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='4cc62d96-110a-42c6-ab0d-90f1df4bad19', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='795d7498-ae87-4210-aeba-c8a05055aba4', ...)
# WARNING:root:Dropping a patch because it contains a previously known reference (id='8a11d509-4740-480e-9708-ae14bed09ab5'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='ee64edb7-98bc-42a0-ad5c-ef4cd2e8cf38'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='099743c7-4f71-41aa-91d0-6a44973d526f'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='5fee0f76-8fee-40de-910e-60ba44db4655'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='93469ba8-8b83-4591-9dd0-a3b00992a64b'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='c10b8b2a-c4cf-4eae-bbb5-021a4e8b4795'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='a2f5acd0-2755-45df-9c1e-5f558e8ab728'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='ba76b8af-3de6-40ba-b178-87b23954466c'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='868d7a87-3c51-45d6-a38c-8c96056ab253'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='93d37ce0-ae18-474c-b464-2f4430fc0757'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='0e1cc43d-ce39-46e1-84da-6d85c8f45685'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='94653e16-5c90-4857-86e5-1cad77ae29a7'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='95a7bf05-8150-49da-b6ce-363173e502c7'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='a33b5578-906e-4ac2-8367-bf8d1368c716'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='d0028f5d-e78c-45f6-a39f-bb1f4275961a'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='53944f9c-9549-4b03-925c-143605489820'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='b9516a68-1c8d-459e-8614-81c127c52b8f'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='74f2923c-292b-4957-b325-918da9aef6b6'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='3b51fca3-d00a-4637-9f12-cfead02abbfb'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='20ea49ec-a771-4203-bad4-dacc56f81aa4'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='3e19421e-01e1-4a67-9d10-cafafc9b3a68'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='a63f65d2-eeba-44a4-a57d-0553959e9d5e'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='602df793-456c-45b3-955b-484c84afd4d2'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='3c951475-8edc-4ea6-ac5d-79a5196bf801'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='151a87fa-1fa4-4469-ab40-65b25d291ba5'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='d9904296-3169-4860-97a6-034a5164fc5e'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='a69371c3-8d1b-46af-bf90-46e5a9126fc2'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.

# %% [markdown]
# ### Fig. 4.2 TwoStableNodesOneSaddlePoint

# %%
table_name = 'TwoStableNodesOneSaddlePoint_c' 
path = "./results/thesis/4-2_preliminary_results/2SN1SP"
model_name = 'TwoStableNodesOneSaddlePoint'

key = '1' 
create_plot_and_save_patchwork(db_name, table_name, run_ids(run_dict, model_name, key), 
                                entropy_strategy_strg=entropy_strategy, 
                                entropy_measure = entropy_measure,
                                loss_function_strg=loss_function, 
                                #path_to_save=path, 
                                title_interactive=title(run_dict, model_name, key, entropy_strategy, entropy_measure), show_interactive=True)
# Out:
# All configurations are the same: True
# Percentage of data rows deleted: 0.00%
# Step 0, number of patches: 900, time: 0.00
# Step 100, number of patches: 800, time: 2.64
# Step 200, number of patches: 700, time: 6.18
# Step 300, number of patches: 600, time: 9.56
# Step 400, number of patches: 500, time: 12.79
# Step 500, number of patches: 400, time: 15.69
# Step 600, number of patches: 300, time: 17.31
# Step 700, number of patches: 200, time: 18.37
# Step 800, number of patches: 100, time: 19.40
# No more patches to merge
# Done, after 899 steps
# /home/kstiller/masterthesis/Coding/mdp-world-model/clustering/patchwork_visualization.py:490: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   fig.tight_layout(pad=0.1)               # remove extra padding
# Launching server at http://localhost:38303
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='254c7d7a-4750-4def-8c7a-4bd371af4ff5', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='08947547-e020-4c80-8036-0a00bc0207d2', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='b228b0a7-9bbf-4e29-840c-fc391c987142', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='85851cba-33a4-4382-8950-7cf3e753dd49', ...)
# WARNING:root:Dropping a patch because it contains a previously known reference (id='9a665953-94b9-4a59-870d-01effe9c7920'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='161ee059-ad25-402e-9700-ac1a424fe20e'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='5b8e9992-6929-4d7f-bac1-0a15f338254c'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='5f7d76c4-28c9-43c0-9588-07dadda9a65f'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='cfd76285-cdc1-4d5d-ac32-e2e1d2ce2ceb'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='8f75848b-b3cf-4a53-b2fa-7e8ed3babcc4'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='ca269c5c-3241-444c-8ad6-16e9dcb54be9'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='081c662d-9e1e-430a-8b97-31bea1df9deb'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='e94dc7be-a8a2-4ced-aa2a-0a8ed90374b5'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='69498205-e035-4ab7-b2db-6cdfe15ee8d4'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='0f3fc3b8-d6c3-4225-8a0c-d207c7b0bf98'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='8fc3cf6a-d9e0-45d1-94a3-fbe2d2c96184'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='3723558b-a37a-442e-ac76-4d97d18602f1'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='91eb732b-c47c-4778-8a2a-a803c67c0b7a'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='2d749721-6457-403d-9191-b0bf5d8fc165'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='e311a1a8-2e5b-4f55-a0d9-efff70f34d1c'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='43076b18-16bc-4ca2-abb6-1cf6706f2c8c'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='cf3370d3-5378-4f78-86e4-853622948193'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='a507f506-311a-482b-b4ec-9f6bc84dfac5'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='bd7ccd28-e003-4d81-b4f7-cf16bc4ff6ca'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='41dc1e8f-e910-4ce2-a8a3-500e0a0dd0a1'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='a5ac6f40-6a54-44ba-9b3d-d0f623f20090'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='f872b095-043f-4eed-922b-d12eac7591fb'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='0b283484-d75d-445d-81f6-cf2e4cab32d3'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='04d537e0-486e-4a8d-9daa-abb229dd3faa'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='28e440e1-dac1-4d52-b8fa-ff4f6e081acb'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='423ca446-9f7f-4673-a9e1-15bf29cffe35'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='6984a443-bf53-4c8b-b742-8131af612c9b'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='1b87166e-6278-499f-a395-dbf15f5a082f'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='1f25d44d-a61b-4479-912c-d338132bbf17'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='41a716b5-66ff-432f-a400-30820e327142'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='62b55c93-c0e2-4066-95c9-79652c1955b1'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='71fe9d61-6706-4478-b672-4a890fffb975'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='94124794-a434-409d-bcc1-c14872ba776c'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.

# %% [markdown]
# ### Tests

# %%
db_name = os.path.join(results_dir, 'simple-models_results.db')
with open(OUTPUT_DIR / "simple-models_run-dict.json", "r") as file:
    run_dict = json.load(file)


entropy_strategy = 'ShannonEntropyAll' 
loss_function = 'TransitionEntropyLoss' #'TransitionEntropyLoss' #'TransitionAndSizeEntropyLoss'
entropy_measure = 'shannon_entropy' #'conditional_shannon_entropy' #'shannon_entropy'
#loss_function_coeff = [0, 0.03, 0.1, 0.3, 0.5]
#coeff = 0.03

# %%
table_name = 'Movable2Stable1SaddlePoint_h' 
model_name = 'Movable2Stable1SaddlePoint'
path = "./results/thesis/4-2_preliminary_results/test"

key = '3' 
create_plot_and_save_patchwork(db_name, table_name, run_ids(run_dict, model_name, key), 
                                entropy_strategy_strg=entropy_strategy, 
                                entropy_measure = entropy_measure,
                                loss_function_strg=loss_function, 
                                #path_to_save=path, 
                                title_interactive=title(run_dict, model_name, key, entropy_strategy, entropy_measure), show_interactive=True)
# Out:
# All configurations are the same: True
# Percentage of data rows deleted: 0.00%
# Step 0, number of patches: 900, time: 0.00
# Step 100, number of patches: 800, time: 10.67
# Step 200, number of patches: 700, time: 19.00
# Step 300, number of patches: 600, time: 26.80
# Step 400, number of patches: 500, time: 32.22
# Step 500, number of patches: 400, time: 37.29
# Step 600, number of patches: 300, time: 41.56
# Step 700, number of patches: 200, time: 47.82
# Step 800, number of patches: 100, time: 54.44
# No more patches to merge
# Done, after 899 steps
# /home/kstiller/masterthesis/Coding/mdp-world-model/clustering/patchwork_visualization.py:490: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   fig.tight_layout(pad=0.1)               # remove extra padding
# Launching server at http://localhost:37737
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='14c14cb6-7f2e-4762-9b19-7e67e1126ea4', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='e3f81709-3304-4ece-88d9-cf929dac50c7', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='fe6a5e95-5354-4d52-82f7-5910fbcd2f28', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='7b69f6e4-1ee1-4389-b03d-4678e2d31231', ...)
# WARNING:root:Dropping a patch because it contains a previously known reference (id='5a8ff9d8-81e2-456f-8fd8-aad0a2a0bdea'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='92567604-f8c3-42a7-90f0-b219fd7d5060'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='dcac4162-26cf-404c-b57d-05344faea25a'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.

# %% [markdown]
# ## 4.4 Added Size Loss

# %% [markdown]
# ### Fig. 4.13 Uniform Flow with Size Loss

# %%
db_name = os.path.join(results_dir, 'simple-models_thesis_results.db')
with open(OUTPUT_DIR / "simple-models_thesis_run-dict.json", "r") as file:
    run_dict = json.load(file)
entropy_strategy = 'ShannonEntropyAll' 
loss_function = 'TransitionAndSizeEntropyLoss' #'TransitionEntropyLoss' #'TransitionAndSizeEntropyLoss'
entropy_measure = 'shannon_entropy'

# %%
# Here I've tried the following coeffs: 0.3, 0.6, 0,7, 0, 8, 1, 1.2
# For coeff = 0.6 the patch size distribution is quite balanced, but still only row patches are formed.

table_name = 'UniformFlow_c' 
path = "./results/thesis/4-4_size_loss/uniform_flow"
model_name = 'UniformFlow'
key = '1'

create_plot_and_save_patchwork(db_name, table_name, run_ids(run_dict, model_name, key), 
                                   entropy_strategy_strg=entropy_strategy, 
                                   entropy_measure = entropy_measure,
                                   loss_function_strg=loss_function, 
                                   loss_function_coeff=0.6,
                                   #path_to_save= path, 
                                   title_interactive=title(run_dict, model_name, key, entropy_strategy), 
                                   show_interactive=True)
# Out:
# All configurations are the same: True
# Percentage of data rows deleted: 2.00%
# Step 0, number of patches: 900, time: 0.00
# Step 100, number of patches: 800, time: 1.70
# Step 200, number of patches: 700, time: 2.94
# Step 300, number of patches: 600, time: 4.19
# Step 400, number of patches: 500, time: 5.20
# Step 500, number of patches: 400, time: 6.10
# Step 600, number of patches: 300, time: 6.81
# Step 700, number of patches: 200, time: 7.45
# Step 800, number of patches: 100, time: 7.94
# No more patches to merge
# Done, after 899 steps
# /home/kstiller/masterthesis/Coding/mdp-world-model/clustering/patchwork_visualization.py:490: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   fig.tight_layout(pad=0.1)               # remove extra padding
# Launching server at http://localhost:46623
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='070faac1-5e35-44e3-8548-2b27abb2e5d3', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='691ac6f2-3a29-4b62-9f41-547719a60b9d', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='71de13db-c9b4-4974-b7b9-06be4bd3aac6', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='cfd9bd1f-0948-409c-9e1f-2e2770d7fcc2', ...)
# WARNING:root:Dropping a patch because it contains a previously known reference (id='c3461d77-bd76-442c-bc4b-8ef8c8a75eae'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='5eaf206f-aa2d-4fe7-a4ee-395cc8d4320b'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='50893fe3-11a9-46f9-98ac-abc05b0e50f3'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.

# %% [markdown]
# ### Fig. 4.14 TwoStableNodesOneSaddlePoint

# %%
table_name = 'TwoStableNodesOneSaddlePoint_c' 
path = "./results/thesis/4-4_size_loss/2SN1SP"
model_name = 'TwoStableNodesOneSaddlePoint'

key = '1' 

# Here I've tried the following coeffs: 0.1, 0.15,  0.2, 0.3, 0.4, 0.6
# 0.2 seems to be a good compromise, and shows some variety in things that go well, and those that don't.

create_plot_and_save_patchwork(db_name, table_name, run_ids(run_dict, model_name, key), 
                                entropy_strategy_strg=entropy_strategy, 
                                entropy_measure = entropy_measure,
                                loss_function_strg=loss_function, 
                                loss_function_coeff=0.2,
                                #path_to_save=path, 
                                title_interactive=title(run_dict, model_name, key, entropy_strategy, entropy_measure), show_interactive=True)
# Out:
# All configurations are the same: True
# Percentage of data rows deleted: 0.00%
# Step 0, number of patches: 900, time: 0.00
# Step 100, number of patches: 800, time: 2.50
# Step 200, number of patches: 700, time: 5.02
# Step 300, number of patches: 600, time: 6.88
# Step 400, number of patches: 500, time: 9.17
# Step 500, number of patches: 400, time: 10.69
# Step 600, number of patches: 300, time: 12.02
# Step 700, number of patches: 200, time: 13.58
# Step 800, number of patches: 100, time: 14.54
# No more patches to merge
# Done, after 899 steps
# /home/kstiller/masterthesis/Coding/mdp-world-model/clustering/patchwork_visualization.py:490: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   fig.tight_layout(pad=0.1)               # remove extra padding
# Launching server at http://localhost:34487
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='8d772d5c-c47e-4ef3-acb9-ea93ac3e6330', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='67e60f08-13d8-45f0-af26-6fe35bb4336a', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='6e467b6c-269d-4ca0-be43-1f81da69ca64', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='2be3c3ef-c6e6-4a12-8491-623f4b3d96f5', ...)
# WARNING:root:Dropping a patch because it contains a previously known reference (id='9a0f6630-c69d-4682-952d-97f9a92100e0'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='a8861387-fd2c-48cb-a66b-7f08d182fab5'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.

# %% [markdown]
# ### Fig. 4.15 Movable TwoStableNodesOneSaddlePoint

# %%
db_name = os.path.join(results_dir, 'simple-models_results.db')
with open(OUTPUT_DIR / "simple-models_run-dict.json", "r") as file:
    run_dict = json.load(file)


entropy_strategy = 'ShannonEntropyAll' 
loss_function = 'TransitionAndSizeEntropyLoss' #'TransitionEntropyLoss' #'TransitionAndSizeEntropyLoss'
entropy_measure = 'shannon_entropy' #'conditional_shannon_entropy' #'shannon_entropy'
#loss_function_coeff = [0, 0.03, 0.1, 0.3, 0.5]
#coeff = 0.03

# %%
table_name = 'Movable2Stable1SaddlePoint_h' 
model_name = 'Movable2Stable1SaddlePoint'
path = "./results/thesis/4-2_preliminary_results/test"

key = '2' 

create_plot_and_save_patchwork(db_name, table_name, run_ids(run_dict, model_name, key), 
                                   entropy_strategy_strg=entropy_strategy, 
                                   entropy_measure = entropy_measure,
                                   loss_function_strg=loss_function, 
                                   loss_function_coeff=0.025,
                                   #path_to_save= path, 
                                   title_interactive=title(run_dict, model_name, key, entropy_strategy), 
                                   show_interactive=True)
# Out:
# All configurations are the same: True
# Percentage of data rows deleted: 0.00%
# Step 0, number of patches: 1600, time: 0.00
# Step 100, number of patches: 1500, time: 9.10
# Step 200, number of patches: 1400, time: 18.69
# Step 300, number of patches: 1300, time: 27.48
# Step 400, number of patches: 1200, time: 35.16
# Step 500, number of patches: 1100, time: 40.79
# Step 600, number of patches: 1000, time: 48.87
# Step 700, number of patches: 900, time: 53.87
# Step 800, number of patches: 800, time: 59.70
# Step 900, number of patches: 700, time: 65.35
# Step 1000, number of patches: 600, time: 73.78
# Step 1100, number of patches: 500, time: 79.93
# Step 1200, number of patches: 400, time: 83.88
# Step 1300, number of patches: 300, time: 89.12
# Step 1400, number of patches: 200, time: 93.90
# Step 1500, number of patches: 100, time: 96.18
# No more patches to merge
# Done, after 1599 steps
# Launching server at http://localhost:40337
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='767920a0-127c-448a-8adf-d83bdd1d4b00', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='e33dbe84-dcbd-40fa-b6d2-a018736d13b6', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='8035ccd3-0a29-4e95-b287-1dea78c0b8ce', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='d50d6ce4-24c6-467e-9094-a3a3c2456e90', ...)
# WARNING:root:Dropping a patch because it contains a previously known reference (id='3748ca93-d17d-4f2e-a8e7-200b2d403c9b'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='dbe3b3ae-3f7a-4150-aa0f-137d289d59ec'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='4883e59a-4701-4840-ae7c-1a4a67429ccf'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='998811a7-0892-4387-ba68-ab16801b18c7'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='29c6fd11-a358-4f0f-a717-a12da4ec9837'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='1e21555e-a0e1-40ae-bc30-cdcf46737f75'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='d6dca406-a68d-4b43-9e9b-24fc1a85b53d'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.

# %%
coeffs = [0.025, 0.1, 0.15, 0.2] #[0.1, 0.2, 0.4, 0.8]
# for 0.025 almost perfect result
# for 0.2 better size distribution, but some errors in the end (aber fast schlechter für 0.1), interessant maybe noch 0.15
# FRAGEE!!

for coeff in coeffs:
    create_plot_and_save_patchwork(db_name, table_name, run_ids(run_dict, model_name, key), 
                                entropy_strategy_strg=entropy_strategy, 
                                entropy_measure = entropy_measure,
                                loss_function_strg=loss_function, 
                                loss_function_coeff=coeff,
                                #path_to_save=path, 
                                title_interactive=title(run_dict, model_name, key, entropy_strategy, entropy_measure), show_interactive=True)
# Out:
# All configurations are the same: True
# Percentage of data rows deleted: 0.00%
# Step 0, number of patches: 900, time: 0.00
# Step 100, number of patches: 800, time: 5.16
# Step 200, number of patches: 700, time: 9.67
# Step 300, number of patches: 600, time: 14.74
# Step 400, number of patches: 500, time: 18.66
# Step 500, number of patches: 400, time: 22.94
# Step 600, number of patches: 300, time: 27.22
# Step 700, number of patches: 200, time: 30.01
# Step 800, number of patches: 100, time: 32.04
# No more patches to merge
# Done, after 899 steps
# Launching server at http://localhost:33871
# All configurations are the same: True
# Percentage of data rows deleted: 0.00%
# Step 0, number of patches: 900, time: 0.00
# Step 100, number of patches: 800, time: 4.89
# Step 200, number of patches: 700, time: 9.20
# Step 300, number of patches: 600, time: 13.71
# Step 400, number of patches: 500, time: 18.24
# Step 500, number of patches: 400, time: 23.57
# Step 600, number of patches: 300, time: 27.70
# Step 700, number of patches: 200, time: 30.80
# Step 800, number of patches: 100, time: 33.14
# No more patches to merge
# Done, after 899 steps
# Launching server at http://localhost:37041
# All configurations are the same: True
# Percentage of data rows deleted: 0.00%
# Step 0, number of patches: 900, time: 0.00
# Step 100, number of patches: 800, time: 5.34
# Step 200, number of patches: 700, time: 10.18
# Step 300, number of patches: 600, time: 14.54
# Step 400, number of patches: 500, time: 18.60
# Step 500, number of patches: 400, time: 22.35
# Step 600, number of patches: 300, time: 25.66
# Step 700, number of patches: 200, time: 28.55
# Step 800, number of patches: 100, time: 30.84
# No more patches to merge
# Done, after 899 steps
# Launching server at http://localhost:44977
# All configurations are the same: True
# Percentage of data rows deleted: 0.00%
# Step 0, number of patches: 900, time: 0.00
# Step 100, number of patches: 800, time: 5.05
# Step 200, number of patches: 700, time: 9.94
# Step 300, number of patches: 600, time: 14.53
# Step 400, number of patches: 500, time: 18.30
# Step 500, number of patches: 400, time: 21.57
# Step 600, number of patches: 300, time: 25.12
# Step 700, number of patches: 200, time: 27.83
# Step 800, number of patches: 100, time: 30.00
# No more patches to merge
# Done, after 899 steps
# Launching server at http://localhost:45929
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='c2a4247d-2b11-4c54-b2cf-aa78fde2957e', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='4e21a76f-6242-4fc7-a1a7-1e9e934e46f8', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='54e4f1cb-bb34-4a03-bb98-a7c012f7385d', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='f9de6ea1-8cbb-4862-b25f-3419157dbd85', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='e126e4b6-8c77-4da4-aa9b-f4e6d09639da', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='dfd633a6-24a2-4131-824d-b3515c53a2b1', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='03a6a94b-36d6-43e2-b9d8-0139ab615319', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='2efe5e36-c0ba-4259-bcce-50f9cbda77ef', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='d959c284-b627-48e6-adf5-045fd40036dc', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='88c43ebe-dd00-413f-a53b-b6684822ac14', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='97c4dca9-28c1-4e97-ba40-3fafa6e8d548', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='b90710fb-d9bf-42b2-bddd-017c2816216f', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='7a053796-29ec-447a-ac6d-220f23ea0272', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='45a7ef15-90f2-4e34-9bee-7c24dff2c307', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='b92e7392-8898-472f-a6dd-99d152428b8e', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='9e03f094-68c7-42fa-9ce8-02f666decf99', ...)
# WARNING:root:Dropping a patch because it contains a previously known reference (id='227233c1-fb09-4335-bc49-35a7f654dcaf'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='3479fa87-aa9c-408b-a58c-8f3cf5bc93dd'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='dedb6bbf-484b-4a71-a001-617fc08bec02'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='7e7e87ad-3fd6-4fbf-b55b-27ffc56b0a94'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='a2463e00-9779-420b-83fa-882a8748b3d6'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='9da06ab5-c805-4f82-a167-ea152bbc205a'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='5f5a15cb-ca0b-4657-a334-4f78ffb264df'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='258b7a3e-8f55-46e2-9150-118b1f9302e6'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='e2a1bd4f-9d22-4646-87f8-bec41fb105ac'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='add6014e-c887-455d-b1a6-6925b40c1256'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='277870d7-66c3-41d1-82fe-bc50d1b560d2'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='5d7dfb2e-c108-43c5-b444-44b6d1a052f7'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='d67a4bf6-830a-41b1-bb93-784c0ce30f24'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='dea0474b-c8b7-4033-96da-6da3c07c6b8e'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='d7cbe6c5-621d-459e-8ffc-1b113354756c'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='23718c0c-371c-49f5-8fe0-8671f22dda69'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='0aa43926-baec-48c4-b6c3-cedd0de8b026'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='9b210eff-9fa9-47f7-b32c-9413cc820bcc'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='973d17aa-9e3b-418a-9db1-638a276a2781'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='468d34b4-a3ef-4f12-9694-c139a2a7653f'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='d940f2a2-54b0-4ba4-8f69-3415fe40cefd'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.

# %%
coeffs = [0.05, 0.15]

for coeff in coeffs:
    create_plot_and_save_patchwork(db_name, table_name, run_ids(run_dict, model_name, key), 
                                entropy_strategy_strg=entropy_strategy, 
                                entropy_measure = entropy_measure,
                                loss_function_strg=loss_function, 
                                loss_function_coeff=coeff,
                                #path_to_save=path, 
                                title_interactive=title(run_dict, model_name, key, entropy_strategy, entropy_measure), show_interactive=True)
# Out:
# All configurations are the same: True
# Percentage of data rows deleted: 0.00%
# Step 0, number of patches: 900, time: 0.00
# Step 100, number of patches: 800, time: 6.10
# Step 200, number of patches: 700, time: 13.60
# Step 300, number of patches: 600, time: 19.63
# Step 400, number of patches: 500, time: 24.45
# Step 500, number of patches: 400, time: 30.01
# Step 600, number of patches: 300, time: 36.53
# Step 700, number of patches: 200, time: 40.95
# Step 800, number of patches: 100, time: 43.45
# No more patches to merge
# Done, after 899 steps
# Launching server at http://localhost:44295
# All configurations are the same: True
# Percentage of data rows deleted: 0.00%
# Step 0, number of patches: 900, time: 0.00
# Step 100, number of patches: 800, time: 5.24
# Step 200, number of patches: 700, time: 9.84
# Step 300, number of patches: 600, time: 15.10
# Step 400, number of patches: 500, time: 20.62
# Step 500, number of patches: 400, time: 25.27
# Step 600, number of patches: 300, time: 29.31
# Step 700, number of patches: 200, time: 33.40
# Step 800, number of patches: 100, time: 36.24
# No more patches to merge
# Done, after 899 steps
# Launching server at http://localhost:39673
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='7a62252b-1b36-403c-a2c5-9515b6e84614', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='9e69951d-15b0-4d19-b50b-d69e5ef1f1df', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='059c632c-34a5-4753-8ee3-47c564601d6a', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='fb3c6a14-d28f-499b-afc8-175a72b266cb', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='a659261a-c691-4872-9746-ad3225db02de', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='c9cce860-b1d0-4672-aa6e-77cc0f87cebf', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='a13fb1b7-8392-44e5-83a0-153ba60a71e0', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='183bc5c8-81b9-45a8-b67c-b67c38f218a8', ...)
# WARNING:root:Dropping a patch because it contains a previously known reference (id='ba9d9474-28fd-4d4f-85b8-d243763ea89a'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='14faf04a-8ac8-4532-88d8-7e8e6c12111e'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='d38e351a-9af7-424a-a31b-cad6b3dd0bf0'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='d042a173-95b2-45d6-9b18-617e386e013b'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='6b23a41c-6a48-4b4a-92a9-2b5f88946dd6'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='b9c8f93d-7717-4b66-ad80-1c98f3b8d989'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='23d7d01e-a65c-4737-9c62-00eb69ec3645'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.

# %% [markdown]
# ## 4.5 Conditional Transition Entropy

# %% [markdown]
# ### Fig. 4.16 Stable Node

# %%
db_name = os.path.join(results_dir, 'simple-models_thesis_results.db')
with open(OUTPUT_DIR / "simple-models_thesis_run-dict.json", "r") as file:
    run_dict = json.load(file)
entropy_strategy = 'ShannonEntropyAll' 
loss_function = 'TransitionAndSizeEntropyLoss' #'TransitionEntropyLoss' #'TransitionAndSizeEntropyLoss'
entropy_measure = 'conditional_shannon_entropy' #'shannon_entropy'

# %%
table_name = 'StableNode_c' 
path = "./results/thesis/4-5_conditional/stable_node"
model_name = 'StableNode'

key = '1' 
# tested also for coeffs = [0.025, 0.1] but seems highly dependent on alpha
create_plot_and_save_patchwork(db_name, table_name, run_ids(run_dict, model_name, key), 
                                entropy_strategy_strg=entropy_strategy, 
                                entropy_measure = entropy_measure,
                                loss_function_strg=loss_function, 
                                loss_function_coeff=0.05,
                                path_to_save=path, 
                                title_interactive=title(run_dict, model_name, key, entropy_strategy, entropy_measure), show_interactive=True)
# Out:
# All configurations are the same: True
# Percentage of data rows deleted: 0.00%
# Step 0, number of patches: 900, time: 0.00
# Step 100, number of patches: 800, time: 2.28
# Step 200, number of patches: 700, time: 4.29
# Step 300, number of patches: 600, time: 6.44
# Step 400, number of patches: 500, time: 8.35
# Step 500, number of patches: 400, time: 10.21
# Step 600, number of patches: 300, time: 12.26
# Step 700, number of patches: 200, time: 14.36
# Step 800, number of patches: 100, time: 15.72
# No more patches to merge
# Done, after 899 steps
# /home/kstiller/masterthesis/Coding/mdp-world-model/clustering/patchwork_visualization.py:490: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   fig.tight_layout(pad=0.1)               # remove extra padding
# Launching server at http://localhost:41239
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='8d8d1414-c2d9-4352-a3b8-e15c27a568f0', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='acfcbbe7-fbfc-4c96-844a-9cfcf30c4081', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='43101bef-b7ea-4964-986d-f41ff5fbd7fc', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='78175249-5368-4ebf-8d50-8c33b08186d1', ...)

# %%
create_plot_and_save_patchwork(db_name, table_name, run_ids(run_dict, model_name, key), 
                                entropy_strategy_strg=entropy_strategy, 
                                entropy_measure = entropy_measure,
                                loss_function_strg=loss_function, 
                                loss_function_coeff=0.2,
                                #path_to_save=path, 
                                title_interactive=title(run_dict, model_name, key, entropy_strategy, entropy_measure), show_interactive=True)

# %%
create_plot_and_save_patchwork(db_name, table_name, run_ids(run_dict, model_name, key), 
                                entropy_strategy_strg=entropy_strategy, 
                                entropy_measure = entropy_measure,
                                loss_function_strg=loss_function, 
                                loss_function_coeff=0.6,
                                #path_to_save=path, 
                                title_interactive=title(run_dict, model_name, key, entropy_strategy, entropy_measure), show_interactive=True)
